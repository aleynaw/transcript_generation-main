# %%
import os, statistics, textwrap, glob, json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import seaborn as sns

# %%
output_dir = "plots"
os.makedirs(output_dir, exist_ok=True)

# %%
def compute_distinct1_corpus(messages):
    """
    Given an iterable of text strings, returns the global Distinct‑1
    (unique unigrams / total unigrams) over the entire corpus.
    """
    tokens = []
    for text in messages:
        if not text:
            continue
        tokens.extend(text.lower().split())
    total = len(tokens)
    return (len(set(tokens)) / total) if total > 0 else 0

def process_json_folder(folder_path):
    """
    Loops over every .json in `folder_path`, computes and stores each file's
    Distinct‑1 for assistant & user, then returns:
      - file_scores: { filename: {'assistant':…, 'user':…}, … }
      - avg_scores:  {'assistant': avg_assistant, 'user': avg_user}
    """
    file_scores     = {}
    assistant_list  = []
    user_list       = []

    for fname in os.listdir(folder_path):
        if not fname.lower().endswith(".json"):
            continue

        fullpath = os.path.join(folder_path, fname)
        with open(fullpath, encoding="utf-8") as f:
            data = json.load(f)

        # extract texts by role
        assistant_texts = [item["content"]
                           for item in data
                           if item.get("role") == "assistant"]
        user_texts      = [item["content"]
                           for item in data
                           if item.get("role") == "user"]

        a_score = compute_distinct1_corpus(assistant_texts)
        u_score = compute_distinct1_corpus(user_texts)

        file_scores[fname] = {"assistant": a_score, "user": u_score}
        assistant_list.append(a_score)
        user_list.append(u_score)

    avg_scores = {
        "assistant": statistics.fmean(assistant_list) if assistant_list else 0,
        "user":      statistics.fmean(user_list)      if user_list     else 0
    }

    return file_scores, avg_scores

# %%
if __name__ == "__main__":
    folder = "25_03_Transcripts"
    per_file, averages = process_json_folder(folder)

    print("Distinct‑1 per file:")
    for fn, scores in per_file.items():
        print(f"  {fn}: assistant={scores['assistant']:.4f}, user={scores['user']:.4f}")

    print("\nAverage Distinct‑1 across all files:")
    print(f"  assistant: {averages['assistant']:.4f}")
    print(f"  user:      {averages['user']:.4f}")

    # Collect scores
    filenames         = sorted(per_file.keys())
    assistant_scores  = [per_file[f]['assistant'] for f in filenames]
    user_scores       = [per_file[f]['user']      for f in filenames]

    # --- Beeswarm plot with median lines ---
    plt.figure(figsize=(6, 6))

    # Jittered x-positions around 0 for user, around 1 for assistant
    jitter_u = np.random.normal(loc=0, scale=0.04, size=len(user_scores))
    jitter_a = np.random.normal(loc=1, scale=0.04, size=len(assistant_scores))

    plt.scatter(jitter_u, user_scores,      alpha=0.7, label='User')
    plt.scatter(jitter_a, assistant_scores, alpha=0.7, label='Assistant')

    # Median indicators
    med_u = np.median(user_scores)
    med_a = np.median(assistant_scores)
    plt.hlines(med_u, -0.2, 0.2, linestyles='--')
    plt.hlines(med_a,  0.8, 1.2, linestyles='--')

    # Formatting
    plt.xlim(-0.5, 1.5)
    plt.xticks([0, 1], ['User', 'Assistant'])
    plt.ylabel('Distinct-1 Score')
    plt.title('Beeswarm of Distinct-1 Scores by Role')
    plt.legend()
    plt.tight_layout()

    # Save & show
    plot_path = os.path.join(output_dir, 'distinct1_beeswarm.png')
    plt.savefig(plot_path)
    print(f"Saved beeswarm plot to {plot_path}")
    plt.show()

    # # Bar positions and width
    # indices = np.arange(len(filenames))
    # bar_width = 0.35

    # # Dynamic figure width
    # fig_width = max(10, len(filenames) * 0.2)
    # plt.figure(figsize=(fig_width, 6))

    # # Plot grouped bars
    # plt.bar(indices, user_scores, bar_width, label='User')
    # plt.bar(indices + bar_width, assistant_scores, bar_width, label='Assistant')

    # # X-axis ticks and labels
    # plt.xticks(indices + bar_width/2, [i + 1 for i in indices], rotation=45, ha='right', fontsize=8)

    # # Labels and title
    # plt.xlabel('Transcript #')
    # plt.ylabel('Distinct-1 Score')
    # plt.title('Distinct-1 per Transcript by Role')
    # plt.legend()
    # plt.tight_layout()

    # # Save and display
    # plot_path = os.path.join(output_dir, 'distinct1_barplot.png')
    # plt.savefig(plot_path)
    # print(f"Saved barplot to {plot_path}")
    # plt.show()

    
    # # Prepare data for violin plot
    # filenames = sorted(per_file.keys())
    # assistant_scores = [per_file[f]['assistant'] for f in filenames]
    # user_scores      = [per_file[f]['user']      for f in filenames]

    # # Build a DataFrame for seaborn
    # df_v = pd.DataFrame({
    #     "Role": ["User"] * len(user_scores) + ["Assistant"] * len(assistant_scores),
    #     "Distinct1": user_scores + assistant_scores
    # })

    # # Plot violin
    # plt.figure(figsize=(8, 6))
    # sns.violinplot(x="Role", y="Distinct1", data=df_v)
    # plt.xlabel("Role")
    # plt.ylabel("Distinct-1 Score")
    # plt.title("Violin Plot of Distinct-1 Scores by Role")
    # plt.tight_layout()

    # # Save & show
    # violin_path = os.path.join(output_dir, "distinct1_violinplot.png")
    # plt.savefig(violin_path)
    # print(f"Saved violin plot to {violin_path}")
    # plt.show()
    
    # # --- Prepare data for the boxplot ---
    # filenames = sorted(per_file.keys())
    # assistant_scores = [per_file[f]['assistant'] for f in filenames]
    # user_scores      = [per_file[f]['user']      for f in filenames]

    # # --- Draw boxplot instead of lineplot ---
    # plt.figure(figsize=(8, 6))
    # plt.boxplot(
    #     [user_scores, assistant_scores],
    #     labels=["User", "Assistant"],
    #     patch_artist=True
    # )
    # plt.ylabel("Distinct-1 Score")
    # plt.title("Distribution of Distinct-1 Scores by Role")

    # # Save & show
    # plot_path = os.path.join(output_dir, 'distinct1_boxplot.png')
    # plt.savefig(plot_path)
    # print(f"Saved boxplot to {plot_path}")
    # plt.show()
    
    # # 2) Plot scores (make sure this is indented under the if-block)
    # filenames = sorted(per_file.keys())
    # assistant_scores = [per_file[f]['assistant'] for f in filenames]
    # user_scores      = [per_file[f]['user']      for f in filenames]
    # x = range(len(filenames))
    # avg_assistant = averages['assistant']
    # avg_user      = averages['user']

    # # Dynamically size figure
    # num_ticks      = len(filenames)
    # fig_width      = max(10, num_ticks * 0.2)
    # plt.figure(figsize=(fig_width, 6))
    
    # plt.plot(x, user_scores,      marker='o', linestyle='-', label='User',      color='blue')
    # plt.plot(x, assistant_scores, marker='o', linestyle='-', label='Assistant', color='red')
    # plt.axhline(avg_user,      linestyle='--', color='blue', label=f'User Avg ({avg_user:.3f})')
    # plt.axhline(avg_assistant, linestyle='--', color='red',  label=f'Assistant Avg ({avg_assistant:.3f})')
    # # Every tick, rotated and readable
    # plt.xticks(
    #     x,
    #     [i+1 for i in x],
    #     fontsize=8
    # )
    # # plt.subplots_adjust(bottom=0.25)
    # plt.xlabel('Transcript #')  
    # plt.ylabel('Distinct-1 Score')
    # plt.title('Distinct-1 per Transcript by Role')
    # plt.legend()
    # plt.tight_layout()

    # plot_path = os.path.join(output_dir, 'distinct1_lineplot.png')
    # plt.savefig(plot_path)
    # print(f"Saved plot to {plot_path}")
    # plt.show()
# Out:
# Distinct‑1 per file:
#   DM_20250313-183641_Interview.json: assistant=0.3574, user=0.4245
#   DM_20250313-122155_Interview.json: assistant=0.3462, user=0.4350
#   DM_20250313-205138_Interview.json: assistant=0.3652, user=0.4671
#   DM_20250314-123247_Interview.json: assistant=0.3456, user=0.4359
#   DM_20250313-072430_Interview.json: assistant=0.3149, user=0.3953
#   DM_20250314-014924_Interview.json: assistant=0.3212, user=0.4206
#   DM_20250313-035214_Interview.json: assistant=0.3416, user=0.4198
#   DM_20250314-125859_Interview.json: assistant=0.2695, user=0.3525
#   DM_20250313-021315_Interview.json: assistant=0.3421, user=0.4356
#   DM_20250313-233249_Interview.json: assistant=0.3615, user=0.4202
#   DM_20250313-084757_Interview.json: assistant=0.3377, user=0.4246
#   DM_20250313-141135_Interview.json: assistant=0.0911, user=0.1004
#   DM_20250314-002211_Interview.json: assistant=0.5745, user=0.8039
#   DM_20250313-131405_Interview.json: assistant=0.3418, user=0.4584
#   DM_20250313-235756_Interview.json: assistant=0.3472, user=0.4854
#   DM_20250313-024039_Interview.json: assistant=0.2936, user=0.3296
#   DM_20250313-181027_Interview.json: assistant=0.3330, user=0.4462
#   DM_20250313-082054_Interview.json: assistant=0.3553, user=0.4662
#   DM_20250314-004854_Interview.json: assistant=0.3382, user=0.4494
#   DM_20250313-124733_Interview.json: assistant=0.3535, user=0.4602
#   DM_20250313-041904_Interview.json: assistant=0.3566, user=0.4732
#   DM_20250312-182025_Interview.json: assistant=0.3447, user=0.4721
#   DM_20250313-192932_Interview.json: assistant=0.3375, user=0.4361
#   DM_20250312-172958_Interview.json: assistant=0.3247, user=0.4463
#   DM_20250312-184417_Interview.json: assistant=0.3183, user=0.4140
#   DM_20250313-174338_Interview.json: assistant=0.3274, user=0.4412
#   DM_20250314-002504_Interview.json: assistant=0.3348, user=0.5100
#   DM_20250313-051233_Interview.json: assistant=0.3280, user=0.4183
#   DM_20250312-214238_Interview.json: assistant=0.2995, user=0.4272
#   DM_20250313-160541_Interview.json: assistant=0.0682, user=0.0658
#   DM_20250312-235953_Interview.json: assistant=0.3641, user=0.4710
#   DM_20250313-002255_Interview.json: assistant=0.3070, user=0.3738
#   DM_20250313-101443_Interview.json: assistant=0.3550, user=0.4669
#   DM_20250314-024748_Interview.json: assistant=0.1256, user=0.1487
#   DM_20250312-210855_Interview.json: assistant=0.2994, user=0.3865
#   DM_20250314-142822_Interview.json: assistant=0.3365, user=0.4376
#   DM_20250313-044329_Interview.json: assistant=0.3224, user=0.3910
#   DM_20250314-113658_Interview.json: assistant=0.3289, user=0.4155
#   DM_20250314-110933_Interview.json: assistant=0.3191, user=0.4116
#   DM_20250313-070020_Interview.json: assistant=0.2858, user=0.3782
#   DM_20250313-014758_Interview.json: assistant=0.3459, user=0.4509
#   DM_20250312-145103_Interview.json: assistant=0.3380, user=0.4650
#   DM_20250313-094834_Interview.json: assistant=0.3215, user=0.4221
#   DM_20250314-011648_Interview.json: assistant=0.5764, user=0.8689
#   DM_20250314-073008_Interview.json: assistant=0.2951, user=0.4099
#   DM_20250314-091639_Interview.json: assistant=0.1129, user=0.0886
#   DM_20250313-224032_Interview.json: assistant=0.3571, user=0.4663
#   DM_20250312-233210_Interview.json: assistant=0.2859, user=0.4791
#   DM_20250313-005318_Interview.json: assistant=0.3315, user=0.4627
#   DM_20250313-195826_Interview.json: assistant=0.3398, user=0.4209
#   DM_20250314-053644_Interview.json: assistant=0.2951, user=0.3794
#   DM_20250313-054006_Interview.json: assistant=0.3421, user=0.4440
#   DM_20250314-120656_Interview.json: assistant=0.3387, user=0.4219
#   DM_20250313-211714_Interview.json: assistant=0.3421, user=0.4120
#   DM_20250314-104714_Interview.json: assistant=0.3550, user=0.4747
#   DM_20250313-111105_Interview.json: assistant=0.1371, user=0.1096
#   DM_20250312-151613_Interview.json: assistant=0.3401, user=0.3969
#   DM_20250313-103940_Interview.json: assistant=0.3131, user=0.4035
#   DM_20250313-221216_Interview.json: assistant=0.3438, user=0.4510
#   DM_20250312-200847_Interview.json: assistant=0.3394, user=0.4631
#   DM_20250313-060648_Interview.json: assistant=0.3388, user=0.4309
#   DM_20250314-085203_Interview.json: assistant=0.3270, user=0.4600
#   DM_20250312-191602_Interview.json: assistant=0.3302, user=0.4446
#   DM_20250313-075457_Interview.json: assistant=0.3432, user=0.4631
#   DM_20250314-080238_Interview.json: assistant=0.3421, user=0.4472
#   DM_20250312-160921_Interview.json: assistant=0.1733, user=0.1416
#   DM_20250313-063540_Interview.json: assistant=0.3258, user=0.4650
#   DM_20250314-063629_Interview.json: assistant=0.3328, user=0.4166
#   DM_20250313-230546_Interview.json: assistant=0.3272, user=0.4371
#   DM_20250313-153233_Interview.json: assistant=0.3169, user=0.4161
#   DM_20250312-221351_Interview.json: assistant=0.1632, user=0.1500
#   DM_20250313-214541_Interview.json: assistant=0.3322, user=0.4350
#   DM_20250314-060900_Interview.json: assistant=0.3494, user=0.4492
#   DM_20250313-133910_Interview.json: assistant=0.2547, user=0.3061
#   DM_20250314-145625_Interview.json: assistant=0.3642, user=0.4574
#   DM_20250312-175504_Interview.json: assistant=0.2251, user=0.3617
#   DM_20250314-140141_Interview.json: assistant=0.3492, user=0.4210
#   DM_20250314-040713_Interview.json: assistant=0.3146, user=0.3815
#   DM_20250314-082733_Interview.json: assistant=0.3554, user=0.4895
#   DM_20250314-021754_Interview.json: assistant=0.3333, user=0.4082
#   DM_20250314-133750_Interview.json: assistant=0.3563, user=0.4532
#   DM_20250313-190204_Interview.json: assistant=0.2546, user=0.4330
#   DM_20250314-044002_Interview.json: assistant=0.2929, user=0.4141
#   DM_20250313-032536_Interview.json: assistant=0.3379, user=0.4212
#   DM_20250313-012001_Interview.json: assistant=0.3648, user=0.4138
#   DM_20250313-091611_Interview.json: assistant=0.3258, user=0.3469
#   DM_20250314-051050_Interview.json: assistant=0.3416, user=0.4622
#   DM_20250306-135826_Interview.json: assistant=0.3430, user=0.3978
#   DM_20250312-193915_Interview.json: assistant=0.3330, user=0.2310
#   DM_20250314-011956_Interview.json: assistant=0.3194, user=0.3783
#   DM_20250314-070638_Interview.json: assistant=0.3457, user=0.4897
#   DM_20250312-154300_Interview.json: assistant=0.3328, user=0.4456
#   DM_20250313-202652_Interview.json: assistant=0.3518, user=0.4270
#   DM_20250312-203320_Interview.json: assistant=0.2949, user=0.3476
#
# Average Distinct‑1 across all files:
#   assistant: 0.3198
#   user:      0.4122
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 17
#      14 plt.figure(figsize=(6, 6))
#      16 # Jittered x-positions around 0 for user, around 1 for assistant
# ---> 17 jitter_u = np.random.normal(loc=0, scale=0.04, size=len(user_scores))
#      18 jitter_a = np.random.normal(loc=1, scale=0.04, size=len(assistant_scores))
#      20 plt.scatter(jitter_u, user_scores,      alpha=0.7, label='User')
#
# NameError: name 'user_scores' is not defined
