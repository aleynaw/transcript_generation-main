# %%
import os, statistics, textwrap, glob, json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
from collections import Counter
import seaborn as sns
import random
from scipy.stats import ttest_ind

# %%
output_dir = "plots"
os.makedirs(output_dir, exist_ok=True)

# %%
def compute_distinct1_corpus(messages):
    """
    Given an iterable of text strings, returns the global Distinct‑1
    (unique unigrams / total unigrams) over the entire corpus.
    """
    tokens = []
    for text in messages:
        if not text:
            continue
        tokens.extend(text.lower().split())
    total = len(tokens)
    return (len(set(tokens)) / total) if total > 0 else 0

def process_json_folder(folder_path):
    """
    Loops over every .json in `folder_path`, computes and stores each file's
    Distinct‑1 for assistant & user, then returns:
      - file_scores: { filename: {'assistant':…, 'user':…}, … }
      - avg_scores:  {'assistant': avg_assistant, 'user': avg_user}
    """
    file_scores     = {}
    assistant_list  = []
    user_list       = []

    for fname in os.listdir(folder_path):
        if not fname.lower().endswith(".json"):
            continue

        fullpath = os.path.join(folder_path, fname)
        with open(fullpath, encoding="utf-8") as f:
            data = json.load(f)

        # extract texts by role
        assistant_texts = [item["content"]
                           for item in data
                           if item.get("role") == "assistant"]
        user_texts      = [item["content"]
                           for item in data
                           if item.get("role") == "user"]

        a_score = compute_distinct1_corpus(assistant_texts)
        u_score = compute_distinct1_corpus(user_texts)

        file_scores[fname] = {"assistant": a_score, "user": u_score}
        assistant_list.append(a_score)
        user_list.append(u_score)

    avg_scores = {
        "assistant": statistics.fmean(assistant_list) if assistant_list else 0,
        "user":      statistics.fmean(user_list)      if user_list     else 0
    }

    return file_scores, avg_scores

# %%
if __name__ == "__main__":
    folder = "25_24_Transcripts"
    per_file, averages = process_json_folder(folder)

     # Collect scores
    filenames         = sorted(per_file.keys())
    assistant_scores  = [per_file[f]['assistant'] for f in filenames]
    user_scores       = [per_file[f]['user']      for f in filenames]

    manual_asst_idxs = [7,8,9,32,64,98,20,77]     # zero-based indices into assistant_scores
    manual_user_idxs = [7,9,32,64,70,98,25,43,46,60,79]   # zero-based indices into user_scores
    
    cleaned_assistant = [
        score
        for i, score in enumerate(assistant_scores)
        if i not in manual_asst_idxs
    ]

    cleaned_user = [
        score
        for i, score in enumerate(user_scores)
        if i not in manual_user_idxs
    ]

    print("Distinct‑1 per file:")
    for fn, scores in per_file.items():
        print(f"  {fn}: assistant={scores['assistant']:.4f}, user={scores['user']:.4f}")

    print("\nAverage Distinct‑1 across all files:")
    print(f"  assistant: {averages['assistant']:.4f}")
    print(f"  user:      {averages['user']:.4f}")

    # cleaned_assistant and cleaned_user already defined
    file_names = list(per_file.keys())

    i = 0
    print("Distinct-1 per file (cleaned):")
    for fn, asst_score, user_score in zip(file_names, cleaned_assistant, cleaned_user):
        i += 1
        print(i)
        print(f"  {fn}: assistant={asst_score:.4f}, user={user_score:.4f}")

    print("\nAverage Distinct-1 across all files (cleaned):")
    print(f"  assistant: {sum(cleaned_assistant)/len(cleaned_assistant):.4f}")
    print(f"  user:      {sum(cleaned_user)/len(cleaned_user):.4f}")
   

    pos_user, pos_assist = 1, 2
    fig, ax = plt.subplots(figsize=(8, 6))

    # 3) Split inliers vs outliers by score
    user_inliers  = [s for s in user_scores      if 0.2 <= s <= 0.55]
    user_outliers = [s for s in user_scores      if s < 0.2  or s > 0.55]
    print("user out:", user_outliers, len(user_outliers))
    as_inliers    = [s for s in assistant_scores if 0.2 <= s <= 0.55]
    as_outliers   = [s for s in assistant_scores if s < 0.2  or s > 0.4]
    print("as out:", as_outliers, len(as_outliers))


    
    
    # 1) Plot User (non-manual)  
    for idx, score in enumerate(user_scores):
        if idx in manual_user_idxs:
            continue      # skip manual here
        x_j = random.gauss(pos_user, 0.04)
        if score < 0.2 or score > 0.55:
            fc, ec, alpha = 'none', 'black', 0.9
        else:
            fc, ec, alpha = 'blue', 'blue', 0.7
        ax.scatter(x_j, score,
                   facecolors=fc,
                   edgecolors=ec,
                   linewidths=1.0,
                   alpha=alpha,
                   zorder=1,
                   label='_nolegend_')

    # 2) Plot Assistant (non-manual)
    for idx, score in enumerate(assistant_scores):
        if idx in manual_asst_idxs:
            continue
        x_j = random.gauss(pos_assist, 0.04)
        if score < 0.2 or score > 0.55:
            fc, ec, alpha = 'none', 'black', 0.9
        else:
            fc, ec, alpha = 'red', 'red', 0.7
        ax.scatter(x_j, score,
                   facecolors=fc,
                   edgecolors=ec,
                   linewidths=1.0,
                   alpha=alpha,
                   zorder=1,
                   label='_nolegend_')

    # 3) Plot Manual highlights last (always on top)
    for idx in manual_user_idxs:
        x_j = random.gauss(pos_user, 0.04)
        y   = user_scores[idx]
        ax.scatter(x_j, y,
                   facecolors='gray',
                   edgecolors='black',
                   linewidths=1.2,
                   alpha=0.9,
                   zorder=3,
                   label='_nolegend_')
    for idx in manual_asst_idxs:
        x_j = random.gauss(pos_assist, 0.04)
        y   = assistant_scores[idx]
        ax.scatter(x_j, y,
                   facecolors='gray',
                   edgecolors='black',
                   linewidths=1.2,
                   alpha=0.9,
                   zorder=3,
                   label='_nolegend_')


    # 5) Draw median lines
    med_user      = statistics.median(user_scores)
    med_assist    = statistics.median(assistant_scores)
    ax.hlines(
        med_user, pos_user-0.2, pos_user+0.2,
        colors='blue',    linestyles='--', linewidth=2,
        label=f'User median ({med_user:.3f})'
    )
    ax.hlines(
        med_assist, pos_assist-0.2, pos_assist+0.2,
        colors='red',     linestyles='--', linewidth=2,
        label=f'Assistant median ({med_assist:.3f})'
    )

    # — Build custom legend handles —
    legend_elements = [
        # Inliers
        Line2D([0], [0],
               marker='o', linestyle='None',
               markerfacecolor='blue', markeredgecolor='blue',
               label='Patient'),
        Line2D([0], [0],
               marker='o', linestyle='None',
               markerfacecolor='red', markeredgecolor='red',
               label='Interview Assistant'),
        # Outliers
        Line2D([0], [0],
               marker='o', linestyle='None',
               markerfacecolor='none', markeredgecolor='black',
               label='Failures'),
        # Manual highlights
        Line2D([0], [0],
               marker='o', linestyle='None',
               markerfacecolor='gray', markeredgecolor='black',
               label='Soft Failures'),
        # Median lines
        Line2D([0], [0],
               linestyle='--', color='blue', linewidth=2,
               label=f'Patient median ({med_user:.3f})'),
        Line2D([0], [0],
               linestyle='--', color='red',  linewidth=2,
                label=f'Interview Assistant median ({med_assist:.3f})'),
    ]

    # 6) Final formatting
    ax.set_xticks([pos_user, pos_assist])
    ax.set_xticklabels(['Patient', 'Interview Assistant'])
    ax.set_ylabel('Distinct-1 Score')
    ax.set_title('Beeswarm of Distinct-1 by Role')
    ax.set_xlim(0.5, 2.5)
    ax.legend(handles=legend_elements, loc='best')
    plt.tight_layout()

    # 7) Save & show
    output_dir = "plots"
    os.makedirs(output_dir, exist_ok=True)
    plot_path = os.path.join(output_dir, 'distinct1_beeswarm.png')
    plt.savefig(plot_path)
    print(f"Saved beeswarm to {plot_path}")
    plt.show()

    
    
    # 2) Plot scores (make sure this is indented under the if-block)
    filenames = sorted(per_file.keys())
    assistant_scores = [per_file[f]['assistant'] for f in filenames]
    user_scores      = [per_file[f]['user']      for f in filenames]
    x = range(len(filenames))
    avg_assistant = averages['assistant']
    avg_user      = averages['user']

    # Dynamically size figure
    num_ticks      = len(filenames)
    fig_width      = max(10, num_ticks * 0.2)
    plt.figure(figsize=(fig_width, 6))
    
    plt.plot(x, user_scores,      marker='o', linestyle='-', label='User',      color='blue')
    plt.plot(x, assistant_scores, marker='o', linestyle='-', label='Assistant', color='red')
    plt.axhline(avg_user,      linestyle='--', color='blue', label=f'User Avg ({avg_user:.3f})')
    plt.axhline(avg_assistant, linestyle='--', color='red',  label=f'Assistant Avg ({avg_assistant:.3f})')
    # Every tick, rotated and readable
    plt.xticks(
        x,
        [i+1 for i in x],
        fontsize=8
    )
    # plt.subplots_adjust(bottom=0.25)
    plt.xlabel('Transcript #')  
    plt.ylabel('Distinct-1 Score')
    plt.title('Distinct-1 per Transcript by Role')
    plt.legend()
    plt.tight_layout()

    plot_path = os.path.join(output_dir, 'distinct1_lineplot.png')
    plt.savefig(plot_path)
    print(f"Saved plot to {plot_path}")
    plt.show()

    # 1) Build inlier lists, excluding the manual indices
    user_inliers = [
        score
        for idx, score in enumerate(user_scores)
        if 0.2 <= score <= 0.55 and idx not in manual_user_idxs
    ]
    assistant_inliers = [
        score
        for idx, score in enumerate(assistant_scores)
        if 0.2 <= score <= 0.4 and idx not in manual_asst_idxs
    ]

    # 2) Run an independent-samples t-test (Welch’s by default)
    t_stat, p_val = ttest_ind(user_inliers, assistant_inliers, equal_var=False)

    # 3) Report
    print(f"User inliers (n={len(user_inliers)}): {user_inliers}")
    print(f"Assistant inliers (n={len(assistant_inliers)}): {assistant_inliers}")
    print(f"T-statistic =", t_stat, "p-value =", p_val)
# Out:
# Distinct‑1 per file:
#   DM_20250427-101833_Interview.json: assistant=0.3154, user=0.4205
#   DM_20250428-041223_Interview.json: assistant=0.1084, user=0.1152
#   DM_20250426-174355_Interview.json: assistant=0.3311, user=0.4897
#   DM_20250426-223017_Interview.json: assistant=0.3499, user=0.4681
#   DM_20250426-161454_Interview.json: assistant=0.2628, user=0.4298
#   DM_20250427-144510_Interview.json: assistant=0.3487, user=0.4683
#   DM_20250427-055904_Interview.json: assistant=0.2976, user=0.3810
#   DM_20250427-221558_Interview.json: assistant=0.3293, user=0.4081
#   DM_20250427-175121_Interview.json: assistant=0.2410, user=0.3204
#   DM_20250427-235930_Interview.json: assistant=0.2501, user=0.3958
#   DM_20250426-085818_Interview.json: assistant=0.5296, user=0.8413
#   DM_20250427-203136_Interview.json: assistant=0.2826, user=0.3371
#   DM_20250427-092438_Interview.json: assistant=0.3003, user=0.1524
#   DM_20250428-031608_Interview.json: assistant=0.3335, user=0.4099
#   DM_20250426-191205_Interview.json: assistant=0.2870, user=0.6421
#   DM_20250427-153721_Interview.json: assistant=0.3234, user=0.4519
#   DM_20250426-133603_Interview.json: assistant=0.3528, user=0.5077
#   DM_20250427-070336_Interview.json: assistant=0.3339, user=0.4298
#   DM_20250428-020343_Interview.json: assistant=0.2561, user=0.4689
#   DM_20250426-092820_Interview.json: assistant=0.1719, user=0.3086
#   DM_20250426-131249_Interview.json: assistant=0.3556, user=0.5063
#   DM_20250426-225436_Interview.json: assistant=0.3109, user=0.4190
#   DM_20250427-063510_Interview.json: assistant=0.3551, user=0.4473
#   DM_20250428-071927_Interview.json: assistant=0.3511, user=0.4620
#   DM_20250428-084737_Interview.json: assistant=0.3166, user=0.3620
#   DM_20250426-164126_Interview.json: assistant=0.3381, user=0.4315
#   DM_20250427-045715_Interview.json: assistant=0.3288, user=0.3915
#   DM_20250426-232536_Interview.json: assistant=0.1438, user=0.0091
#   DM_20250427-110824_Interview.json: assistant=0.5616, user=0.8833
#   DM_20250427-105006_Interview.json: assistant=0.2709, user=0.2594
#   DM_20250427-214525_Interview.json: assistant=0.3382, user=0.4168
#   DM_20250426-215913_Interview.json: assistant=0.2934, user=0.3981
#   DM_20250427-163123_Interview.json: assistant=0.3133, user=0.4136
#   DM_20250426-170932_Interview.json: assistant=0.3121, user=0.3835
#   DM_20250428-055231_Interview.json: assistant=0.3176, user=0.4544
#   DM_20250428-094356_Interview.json: assistant=0.3328, user=0.4109
#   DM_20250428-064335_Interview.json: assistant=0.3295, user=0.4008
#   DM_20250427-052809_Interview.json: assistant=0.3051, user=0.4257
#   DM_20250428-002857_Interview.json: assistant=0.3420, user=0.4863
#   DM_20250426-110108_Interview.json: assistant=0.3621, user=0.4667
#   DM_20250426-090112_Interview.json: assistant=0.3302, user=0.4644
#   DM_20250427-123219_Interview.json: assistant=0.3429, user=0.4827
#   DM_20250426-065703_Interview.json: assistant=0.2988, user=0.4111
#   DM_20250427-111116_Interview.json: assistant=0.3554, user=0.4485
#   DM_20250426-080834_Interview.json: assistant=0.1722, user=0.3968
#   DM_20250426-192303_Interview.json: assistant=0.1031, user=0.1040
#   DM_20250427-200206_Interview.json: assistant=0.3227, user=0.4036
#   DM_20250428-074346_Interview.json: assistant=0.2749, user=0.4299
#   DM_20250427-231043_Interview.json: assistant=0.3288, user=0.4861
#   DM_20250426-140057_Interview.json: assistant=0.3262, user=0.4385
#   DM_20250426-183445_Interview.json: assistant=0.3075, user=0.3538
#   DM_20250427-142047_Interview.json: assistant=0.3335, user=0.4826
#   DM_20250427-193724_Interview.json: assistant=0.3494, user=0.4443
#   DM_20250427-135312_Interview.json: assistant=0.3405, user=0.3908
#   DM_20250427-095421_Interview.json: assistant=0.3595, user=0.4577
#   DM_20250427-211417_Interview.json: assistant=0.3159, user=0.3885
#   DM_20250428-081637_Interview.json: assistant=0.3101, user=0.3971
#   DM_20250428-005326_Interview.json: assistant=0.2844, user=0.3226
#   DM_20250428-104612_Interview.json: assistant=0.3243, user=0.4942
#   DM_20250428-061846_Interview.json: assistant=0.3432, user=0.4795
#   DM_20250427-160614_Interview.json: assistant=0.3040, user=0.3195
#   DM_20250426-155200_Interview.json: assistant=0.3775, user=0.4939
#   DM_20250426-082857_Interview.json: assistant=0.3383, user=0.4110
#   DM_20250427-073238_Interview.json: assistant=0.3312, user=0.4061
#   DM_20250427-132719_Interview.json: assistant=0.2685, user=0.4464
#   DM_20250426-142528_Interview.json: assistant=0.0936, user=0.0928
#   DM_20250427-085605_Interview.json: assistant=0.5516, user=0.8448
#   DM_20250426-072813_Interview.json: assistant=0.3591, user=0.4442
#   DM_20250427-181342_Interview.json: assistant=0.3167, user=0.3926
#   DM_20250427-150925_Interview.json: assistant=0.3396, user=0.3906
#   DM_20250427-233442_Interview.json: assistant=0.3586, user=0.4748
#   DM_20250428-034634_Interview.json: assistant=0.3508, user=0.4618
#   DM_20250428-012836_Interview.json: assistant=0.2902, user=0.3560
#   DM_20250427-132321_Interview.json: assistant=0.5822, user=0.6426
#   DM_20250427-120522_Interview.json: assistant=0.3385, user=0.4457
#   DM_20250427-125714_Interview.json: assistant=0.3509, user=0.4320
#   DM_20250427-113824_Interview.json: assistant=0.3281, user=0.4468
#   DM_20250426-121559_Interview.json: assistant=0.3489, user=0.4394
#   DM_20250426-115019_Interview.json: assistant=0.3320, user=0.4436
#   DM_20250428-022805_Interview.json: assistant=0.3640, user=0.4491
#   DM_20250427-170136_Interview.json: assistant=0.3498, user=0.5122
#   DM_20250428-052121_Interview.json: assistant=0.2974, user=0.4205
#   DM_20250426-204110_Interview.json: assistant=0.1333, user=0.1226
#   DM_20250427-190932_Interview.json: assistant=0.3265, user=0.4045
#   DM_20250426-100032_Interview.json: assistant=0.2068, user=0.4445
#   DM_20250428-091756_Interview.json: assistant=0.3511, user=0.4565
#   DM_20250428-101025_Interview.json: assistant=0.2152, user=0.3308
#   DM_20250427-083016_Interview.json: assistant=0.3491, user=0.4694
#   DM_20250428-071500_Interview.json: assistant=0.4383, user=0.8358
#   DM_20250427-184530_Interview.json: assistant=0.3512, user=0.4563
#   DM_20250427-085854_Interview.json: assistant=0.2522, user=0.4450
#   DM_20250426-075428_Interview.json: assistant=0.2021, user=0.5253
#   DM_20250427-080037_Interview.json: assistant=0.3274, user=0.4052
#   DM_20250427-224455_Interview.json: assistant=0.3571, user=0.4705
#   DM_20250427-172402_Interview.json: assistant=0.3586, user=0.4391
#   DM_20250426-180656_Interview.json: assistant=0.3187, user=0.4401
#   DM_20250426-102610_Interview.json: assistant=0.2387, user=0.3645
#   DM_20250428-025056_Interview.json: assistant=0.3410, user=0.4658
#   DM_20250426-112538_Interview.json: assistant=0.3395, user=0.4698
#   DM_20250426-124359_Interview.json: assistant=0.3273, user=0.3923
#
# Average Distinct‑1 across all files:
#   assistant: 0.3171
#   user:      0.4286
# Distinct-1 per file (cleaned):
# 1
#   DM_20250427-101833_Interview.json: assistant=0.2988, user=0.4111
# 2
#   DM_20250428-041223_Interview.json: assistant=0.3591, user=0.4442
# 3
#   DM_20250426-174355_Interview.json: assistant=0.2021, user=0.5253
# 4
#   DM_20250426-223017_Interview.json: assistant=0.1722, user=0.3968
# 5
#   DM_20250426-161454_Interview.json: assistant=0.3383, user=0.4110
# 6
#   DM_20250427-144510_Interview.json: assistant=0.5296, user=0.8413
# 7
#   DM_20250427-055904_Interview.json: assistant=0.3302, user=0.4644
# 8
#   DM_20250427-221558_Interview.json: assistant=0.3621, user=0.4445
# 9
#   DM_20250427-175121_Interview.json: assistant=0.3395, user=0.4667
# 10
#   DM_20250427-235930_Interview.json: assistant=0.3320, user=0.4698
# 11
#   DM_20250426-085818_Interview.json: assistant=0.3489, user=0.4436
# 12
#   DM_20250427-203136_Interview.json: assistant=0.3273, user=0.4394
# 13
#   DM_20250427-092438_Interview.json: assistant=0.3556, user=0.3923
# 14
#   DM_20250428-031608_Interview.json: assistant=0.3528, user=0.5063
# 15
#   DM_20250426-191205_Interview.json: assistant=0.3262, user=0.5077
# 16
#   DM_20250427-153721_Interview.json: assistant=0.0936, user=0.4385
# 17
#   DM_20250426-133603_Interview.json: assistant=0.3775, user=0.0928
# 18
#   DM_20250427-070336_Interview.json: assistant=0.3381, user=0.4939
# 19
#   DM_20250428-020343_Interview.json: assistant=0.3121, user=0.4298
# 20
#   DM_20250426-092820_Interview.json: assistant=0.3311, user=0.4315
# 21
#   DM_20250426-131249_Interview.json: assistant=0.3187, user=0.3835
# 22
#   DM_20250426-225436_Interview.json: assistant=0.3075, user=0.4897
# 23
#   DM_20250427-063510_Interview.json: assistant=0.2870, user=0.4401
# 24
#   DM_20250428-071927_Interview.json: assistant=0.1031, user=0.6421
# 25
#   DM_20250428-084737_Interview.json: assistant=0.1333, user=0.1040
# 26
#   DM_20250426-164126_Interview.json: assistant=0.2934, user=0.1226
# 27
#   DM_20250427-045715_Interview.json: assistant=0.3499, user=0.3981
# 28
#   DM_20250426-232536_Interview.json: assistant=0.3109, user=0.4681
# 29
#   DM_20250427-110824_Interview.json: assistant=0.3288, user=0.4190
# 30
#   DM_20250427-105006_Interview.json: assistant=0.3051, user=0.3915
# 31
#   DM_20250427-214525_Interview.json: assistant=0.2976, user=0.4257
# 32
#   DM_20250426-215913_Interview.json: assistant=0.3551, user=0.3810
# 33
#   DM_20250427-163123_Interview.json: assistant=0.3339, user=0.4473
# 34
#   DM_20250426-170932_Interview.json: assistant=0.3312, user=0.4298
# 35
#   DM_20250428-055231_Interview.json: assistant=0.3274, user=0.4061
# 36
#   DM_20250428-094356_Interview.json: assistant=0.3491, user=0.4052
# 37
#   DM_20250428-064335_Interview.json: assistant=0.5516, user=0.4694
# 38
#   DM_20250427-052809_Interview.json: assistant=0.2522, user=0.8448
# 39
#   DM_20250428-002857_Interview.json: assistant=0.3003, user=0.4450
# 40
#   DM_20250426-110108_Interview.json: assistant=0.3595, user=0.4577
# 41
#   DM_20250426-090112_Interview.json: assistant=0.3154, user=0.4205
# 42
#   DM_20250427-123219_Interview.json: assistant=0.2709, user=0.8833
# 43
#   DM_20250426-065703_Interview.json: assistant=0.5616, user=0.4485
# 44
#   DM_20250427-111116_Interview.json: assistant=0.3554, user=0.4468
# 45
#   DM_20250426-080834_Interview.json: assistant=0.3281, user=0.4457
# 46
#   DM_20250426-192303_Interview.json: assistant=0.3385, user=0.4827
# 47
#   DM_20250427-200206_Interview.json: assistant=0.3429, user=0.4320
# 48
#   DM_20250428-074346_Interview.json: assistant=0.3509, user=0.6426
# 49
#   DM_20250427-231043_Interview.json: assistant=0.5822, user=0.4464
# 50
#   DM_20250426-140057_Interview.json: assistant=0.2685, user=0.3908
# 51
#   DM_20250426-183445_Interview.json: assistant=0.3405, user=0.4826
# 52
#   DM_20250427-142047_Interview.json: assistant=0.3335, user=0.4683
# 53
#   DM_20250427-193724_Interview.json: assistant=0.3487, user=0.3906
# 54
#   DM_20250427-135312_Interview.json: assistant=0.3396, user=0.4519
# 55
#   DM_20250427-095421_Interview.json: assistant=0.3234, user=0.4136
# 56
#   DM_20250427-211417_Interview.json: assistant=0.3040, user=0.5122
# 57
#   DM_20250428-081637_Interview.json: assistant=0.3133, user=0.4391
# 58
#   DM_20250428-005326_Interview.json: assistant=0.3498, user=0.3926
# 59
#   DM_20250428-104612_Interview.json: assistant=0.3586, user=0.4563
# 60
#   DM_20250428-061846_Interview.json: assistant=0.3167, user=0.4045
# 61
#   DM_20250427-160614_Interview.json: assistant=0.3512, user=0.4443
# 62
#   DM_20250426-155200_Interview.json: assistant=0.3265, user=0.4036
# 63
#   DM_20250426-082857_Interview.json: assistant=0.3494, user=0.3885
# 64
#   DM_20250427-073238_Interview.json: assistant=0.3227, user=0.4168
# 65
#   DM_20250427-132719_Interview.json: assistant=0.2826, user=0.4081
# 66
#   DM_20250426-142528_Interview.json: assistant=0.3159, user=0.4705
# 67
#   DM_20250427-085605_Interview.json: assistant=0.3382, user=0.4861
# 68
#   DM_20250426-072813_Interview.json: assistant=0.3293, user=0.4748
# 69
#   DM_20250427-181342_Interview.json: assistant=0.3571, user=0.3958
# 70
#   DM_20250427-150925_Interview.json: assistant=0.3288, user=0.4863
# 71
#   DM_20250427-233442_Interview.json: assistant=0.3586, user=0.3560
# 72
#   DM_20250428-034634_Interview.json: assistant=0.3420, user=0.4689
# 73
#   DM_20250428-012836_Interview.json: assistant=0.2844, user=0.4491
# 74
#   DM_20250427-132321_Interview.json: assistant=0.2902, user=0.4658
# 75
#   DM_20250427-120522_Interview.json: assistant=0.2561, user=0.4099
# 76
#   DM_20250427-125714_Interview.json: assistant=0.3640, user=0.4618
# 77
#   DM_20250427-113824_Interview.json: assistant=0.3410, user=0.1152
# 78
#   DM_20250426-121559_Interview.json: assistant=0.3335, user=0.4205
# 79
#   DM_20250426-115019_Interview.json: assistant=0.3508, user=0.4544
# 80
#   DM_20250428-022805_Interview.json: assistant=0.1084, user=0.4795
# 81
#   DM_20250427-170136_Interview.json: assistant=0.2974, user=0.4008
# 82
#   DM_20250428-052121_Interview.json: assistant=0.3176, user=0.8358
# 83
#   DM_20250426-204110_Interview.json: assistant=0.3432, user=0.4620
# 84
#   DM_20250427-190932_Interview.json: assistant=0.3295, user=0.4299
# 85
#   DM_20250426-100032_Interview.json: assistant=0.4383, user=0.3971
# 86
#   DM_20250428-091756_Interview.json: assistant=0.3511, user=0.3620
# 87
#   DM_20250428-101025_Interview.json: assistant=0.2749, user=0.4565
# 88
#   DM_20250427-083016_Interview.json: assistant=0.3101, user=0.4109
# 89
#   DM_20250428-071500_Interview.json: assistant=0.3166, user=0.4942
#
# Average Distinct-1 across all files (cleaned):
#   assistant: 0.3259
#   user:      0.4469
# user out: [0.8412698412698413, 0.09275010125556905, 0.6421404682274248, 0.10400911633689008, 0.12257875171199374, 0.009119007027829222, 0.8448275862068966, 0.15235602094240838, 0.8833333333333333, 0.642570281124498, 0.11523871811641596, 0.835820895522388] 12
# as out: [0.17218420565933049, 0.5296296296296297, 0.17194029850746267, 0.09363704562504263, 0.10306686777275012, 0.13331908984082896, 0.14376563058235084, 0.5515695067264574, 0.5615615615615616, 0.5821727019498607, 0.10844572186601813, 0.43833017077798864] 12
# Saved beeswarm to plots/distinct1_beeswarm.png
# Saved plot to plots/distinct1_lineplot.png
# User inliers (n=79): [0.4110576923076923, 0.4442361761949391, 0.5252747252747253, 0.3967828418230563, 0.4109681787406906, 0.4644268774703557, 0.44454628780934924, 0.46673706441393875, 0.46979166666666666, 0.44362969752520626, 0.43944353518821605, 0.392328398384926, 0.506265664160401, 0.5077105575326216, 0.4384976525821596, 0.4938684503901895, 0.4298245614035088, 0.4314789687924016, 0.38348271446862997, 0.4897400820793434, 0.4401064773735581, 0.3981244671781756, 0.46810933940774485, 0.41899441340782123, 0.39147286821705424, 0.4256535947712418, 0.38104089219330856, 0.4473007712082262, 0.42978395061728397, 0.4060810810810811, 0.4051851851851852, 0.46940822467402205, 0.44495412844036697, 0.4577226606538895, 0.4204809930178433, 0.448501872659176, 0.44675090252707583, 0.44570837642192346, 0.4827188940092166, 0.43202979515828677, 0.44644644644644643, 0.3908205841446453, 0.4825765575501584, 0.46825396825396826, 0.3906474820143885, 0.45187165775401067, 0.41362530413625304, 0.5121602288984263, 0.439066551426102, 0.3926332288401254, 0.45629965947786605, 0.4045031055900621, 0.44432989690721647, 0.40364963503649637, 0.38852578068264343, 0.4167862266857963, 0.4081196581196581, 0.47046632124352333, 0.4860606060606061, 0.47477744807121663, 0.39581777445855115, 0.48627450980392156, 0.35600762873490144, 0.4689265536723164, 0.4491341991341991, 0.4657534246575342, 0.4099462365591398, 0.4618249534450652, 0.42048517520215634, 0.4543610547667343, 0.47950428979980936, 0.4007832898172324, 0.46203904555314534, 0.42989864864864863, 0.39712918660287083, 0.3619631901840491, 0.45652173913043476, 0.4108527131782946, 0.4941860465116279]
# Assistant inliers (n=82): [0.29876160990712075, 0.35905224787363305, 0.20211864406779662, 0.33828207847295866, 0.3302379570516541, 0.36211031175059955, 0.3395225464190981, 0.33196511031298104, 0.34890776699029125, 0.32726377952755903, 0.3555956678700361, 0.35276621058893515, 0.3262411347517731, 0.3775322283609576, 0.3380900109769484, 0.31211589113257243, 0.33108522378908645, 0.31872340425531914, 0.3075010360547037, 0.28703134603564845, 0.2933579335793358, 0.3498603351955307, 0.310913140311804, 0.3287541449549976, 0.30509181969949917, 0.2976190476190476, 0.35506849315068495, 0.3339407744874715, 0.33115975780158363, 0.3274087932647334, 0.34912280701754383, 0.25219084712755596, 0.30025062656641605, 0.35951134380453753, 0.3154269972451791, 0.27091633466135456, 0.35542168674698793, 0.3280657395701643, 0.3385074626865672, 0.34291581108829566, 0.3509043927648579, 0.2684865238424326, 0.34045881126173094, 0.33351678591084205, 0.348669623059867, 0.3395931142410016, 0.32336255801959773, 0.30402750491159136, 0.31327514928801103, 0.34980237154150196, 0.3586206896551724, 0.3167095115681234, 0.35116851168511687, 0.3265196342119419, 0.3494047619047619, 0.32266811279826463, 0.2826489086200518, 0.31593662628145386, 0.3382352941176471, 0.3293051359516616, 0.3570581257413998, 0.3288117200217037, 0.3585887796414112, 0.34203220433092724, 0.28437190900098913, 0.29022491349480967, 0.2561340514661879, 0.36396011396011396, 0.341016548463357, 0.33349236641221375, 0.35079365079365077, 0.2973609802073516, 0.3175542406311637, 0.34324659231722426, 0.3294663573085847, 0.3510825043885313, 0.2749019607843137, 0.3100926377376889, 0.31663223140495866, 0.35112692763938314, 0.33278145695364236, 0.3243076923076923]
# T-statistic = 21.422484144983287 p-value = 2.0372436204406393e-47

# %%
# --- Plot only the filtered inliers ---
pos_user, pos_assist = 1, 2
fig, ax = plt.subplots(figsize=(6, 4))

# Jitter & scatter User inliers (blue)
x_user = [random.gauss(pos_user, 0.04) for _ in user_inliers]
ax.scatter(x_user, user_inliers,
           color='blue', alpha=0.7,
           label=f'User inliers (n={len(user_inliers)})')

# Jitter & scatter Assistant inliers (red)
x_asst = [random.gauss(pos_assist, 0.04) for _ in assistant_inliers]
ax.scatter(x_asst, assistant_inliers,
           color='red', alpha=0.7,
           label=f'Assistant inliers (n={len(assistant_inliers)})')

# Median lines (optional)
med_user  = statistics.median(user_inliers)
med_asst  = statistics.median(assistant_inliers)
ax.hlines(med_user,  pos_user-0.2, pos_user+0.2,
          colors='blue',    linestyles='--', linewidth=2,
          label=f'User median ({med_user:.3f})')
ax.hlines(med_asst, pos_assist-0.2, pos_assist+0.2,
          colors='red',    linestyles='--', linewidth=2,
          label=f'Assistant median ({med_asst:.3f})')

# Formatting
ax.set_xticks([pos_user, pos_assist])
ax.set_xticklabels(['User', 'Assistant'])
ax.set_ylabel('Distinct-1 Score')
ax.set_title('Filtered Inlier Distinct-1 Scores')
ax.legend(loc='best')
plt.tight_layout()
plt.show()
