# %%
import sys, os, csv, ast, random, time, re
import pandas as pd
from pathlib import Path
from collections import deque  # Queue for questions
from faker import Faker
from dateutil.relativedelta import relativedelta
from datetime import datetime

from variables import HEALTH_CONDITIONS, COMMON_RECREATIONAL_DRUGS, COMMON_HEALTH_SUPPLEMENTS, COMMON_ALLERGIES, DR_APPOINTMENT_REASONS, TYPING_STYLES, CONVERSATIONAL_TONE, PERSONALITY_TRAITS, EDGE_CASE_SCENARIOS, INDIGENOUS, MIDDLE_EASTERN_REGIONS, EUROPEAN_REGIONS, EAST_ASIAN_REGIONS, SOUTH_ASIAN_REGIONS, SOUTHEAST_ASIAN_REGIONS, LATIN_AMERICAN_REGIONS, AFRICAN_REGIONS, OTHER_REGIONS
import variables
from ethnicity_codes import ETHNICITY_CODES

# import Langchain and Ollama
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate

model1 = OllamaLLM(base_url="localhost:11435", 
                   model="llama3.3:70b", 
                   temperature=0.7, 
                   num_ctx = 4096,
                   top_k = 50,
                   top_p = 0.95)

#llama3.1:70b-instruct-q4_0

# %%
print(Path.cwd())
# Out:
# /home/ninc-user/finetuning/transcript_generation-main/patient_creation

# %%
random.seed()
# This function would take a prompt, a variables file, and then call the LLM to generate a patient profile
def generate_patient_profile(variables):
    '''
    Generates a fictional patient profile by filling in missing details based on structured variables.

    Parameters
    ----------
    variables: dict
        A dictionary containing predefined patient variables, some of which may be incomplete or placeholders.

    Returns
    -------
    dict
        A fully populated patient profile dictionary with realistic details, ensuring coherence and consistency.

    Function Overview
    -----------------
    - Loads the provided `variables` as a dictionary representing patient data.
    - Defines a structured profile template with various categories such as General Information, Medical History, Family History, and Lifestyle.
    - Uses `hydrate_patient_profile` to populate fields with initial values.
    - Identifies missing or placeholder values that require completion.
    - Generates a structured prompt for an LLM to fill in missing details while maintaining logical consistency.
    - Ensures anglicization of names and birthplaces if necessary, adhering to strict formatting requirements.
    - Invokes an LLM (`model1.invoke(prompt)`) to generate missing information.
    - Updates the patient dictionary using `hydrate_dict()` with the newly generated details.
    - Returns the completed patient dictionary.
    '''
    
    # Load variables from a Python file (assuming it's structured as a dictionary)
    patient_variables = variables
    
    # Patient profile template (corresponding to your structured format)
    profile_template = """
    ### General Information
    - Full name: {full_name}
    - Preferred name: {preferred_name}
    - Date of birth: {date_of_birth}
    - Age: {age}
    - Sex: {sex}
    - Handedness: {handedness}
    
    ### Residence and Marital Status
    - Current city/town of residence: {residence}
    - Relationship status: {relationship_status}
    - Children or dependents: {children_status}
      {children_details}
    
    ### Employment and Financial Status
    - Current employment status: {employment_status}
      {employment_details}
    - Disabled: {disabled}
    {disability_details}
    - Disability assistance: {disability_status}
      {disability_assistance_details}
    
    ### Medical Care Information
    - List of current doctors: {doctors}
    - Allergies: {allergies}
    - Current medications and dosages: {medications}
    - Health supplements: {supplements}
    
    ### Substance Use
    - Nicotine, marijuana, alcohol use frequency: {substance_use}
    
    ### Medical History
    - Reason for Appointment: {dr_reason}
    - Health conditions/diagnoses: {health_conditions}
    - Previous hospitalizations or surgeries: {hospitalizations}
    - Head injuries or concussions: {head_injuries}
    - History of seizures: {seizures}
    - Rehab or substance counseling: {rehab_history}
    
    ### Family History
    - Psychiatric conditions in family: {family_psychiatric}
    - Neurological or genetic conditions in family: {family_neurological}
    - Siblings: {siblings}
    
    ### Personal History
    - Birthplace: {birthplace}
    - Canadian citizen: {citizenship_status}
    
    ### Education
    - Difficulties in elementary school: {elementary_difficulties}
    - High school performance: {high_school_performance}
    - Further education after high school: {further_education}
    
    ### Employment and Relationships
    - Previous work history: {previous_work}
    - Previous marriages/long-term relationships: {previous_relationships}
    
    ### Hobbies and Lifestyle
    - Hobbies: {hobbies}
    - How to relax on a stressful day: {relaxation_methods}
    
    ### Personality
    - Conversational tone: {conversational_tone}
    - Typing style: {typing_style}
    - Personality traits: {personality_traits}
    """
    
    # Hydrate randomly generated information
    patient_dict = hydrate_patient_profile(variables, {})
    patient_dict
    
    # fields_to_fill = {k: v for k, v in patient_dict.items() if v == ""}
    
    # Extract fields with placeholders
    fields_to_fill = {k: v for k, v in patient_dict.items() if isinstance(v, str) and v.startswith('{') and v.endswith('}')}

    # Convert to a more readable format for the LLM
    fields_to_fill_str = ', '.join([f"{key}: {value}" for key, value in fields_to_fill.items()])
    print(fields_to_fill_str)

    prompt = f"""
    I have a fictional patient profile, and I need to fill in some sections with realistic-sounding but completely made-up details. 
    Here are the sections with placeholders that need to be completed:

    {fields_to_fill_str}
    

    Please generate brief, suitable details for each section that make sense in the context of a fictional character and their background. The information should be coherent with the rest of the profile provided below,
    and there must NOT be contradicting information. For example, if the patient has no siblings, then there should not be siblings mentioned in the Family History.
    
    
    Here is the partially filled out dict:

    {patient_dict}
    
     If the full name and city of their birthplace are not in the english alphabet, please anglicize them and output it inline with the other fields, as such:
    "Anglicized Full name: value", "Anglicized Clinician Name: value", "Anglicized Birthplace: value", and "Anglicized Doctor Name: value". You MUST adhere to this format, and do not include any more text on the same line as these outputs.
    For the Birthplace, you MUST include the ENTIRETY of the Birthplace name in the value, so please include both the city name AND either the country name or the country code.
    
    YOU MUST return the output in the following format for each section:
    "Field Name: value"
    """


    # Call the LLM
    try:
        response = model1.invoke(prompt)
        
        # Get the generated profile
        print("Response: ", response)
    
    except Exception as e:
        print(f"Error generating patient profile: {e}")
        
    updated_patient_dict = hydrate_dict(patient_dict, response)
    
    return updated_patient_dict

# %%
def generate_health_conditions(n):
    '''
    Generates a list of n random health conditions along with associated medications and dosages.

    Parameters
    ----------
    n: int
        The number of random health conditions to select.

    Returns
    -------
    tuple (list, list)
        - A list of n randomly chosen health conditions.
        - A corresponding list of tuples, where each tuple contains:
          - A randomly selected medication for the condition (if applicable).
          - A randomly selected dosage (starting or therapeutic dose).
          - If no medication is available for a condition, `None` is added to the list.

    Function Overview
    -----------------
    - Randomly selects `n` health conditions from the `HEALTH_CONDITIONS` dictionary.
    - For each condition:
      - If medications exist, there is an 80% chance that a medication is assigned.
      - A random medication is chosen from the available options.
      - A corresponding dosage is selected from the available dosage list.
    - Returns two lists: one with selected health conditions and another with medications and dosages (or `None` if no medication is assigned).
    '''
    
    health_conditions = random.sample(list(HEALTH_CONDITIONS.keys()), n)
    meds_with_dosages = []
    
    for condition in health_conditions:
        meds = list(HEALTH_CONDITIONS[condition].keys())
        
        # Check if there are any medications for the condition
        if len(meds) > 0:
            # 80% chance that meds may be taken for that health condition
            if random.random() <= 0.8:
                med_name = random.choice(meds)
                # Select a random dosage (starting or therapeutic dose)
                dosage = random.choice(list(HEALTH_CONDITIONS[condition][med_name].values()))
                meds_with_dosages.append((med_name, dosage))
        else:
            meds_with_dosages.append(None)
    
    return health_conditions, meds_with_dosages

def create_clinician_name()->str:
    '''Generates a random clinician's name.

    Returns
    -------
    str
        A randomly generated full name for a clinician.

    Function Overview
    -----------------
    - Uses the `Faker` library with an ethnicity-specific provider (`ethnicity_picker()`).
    - Generates a random name.
    - Returns the generated name.'''
    ethnicity, checker = ethnicity_picker()
    
    fake = Faker(ethnicity)
    dr = fake.name()
    return dr

def create_appt_date()->str:
    '''Generates a random appointment date within the next five years.

    Returns
    -------
    str
        A string representing a randomly chosen month and day (e.g., "February 14").

    Function Overview
    -----------------
    - Uses the `Faker` library to generate a random date between today and five years in the future.
    - Formats the date as "<Month> <Day>" (e.g., "March 5").
    - Returns the formatted date.'''
    
    fake = Faker()
    appt_date = fake.date_between("today", "+5y").strftime("%B %#d")
    return appt_date

# %%
# Function to pick a full demographic profile
def pick_demographics(categories, weights):
    '''
    Randomly selects a demographic category based on weighted probabilities.

    Parameters
    ----------
    categories: list
        A list of possible demographic categories to choose from.
    weights: list
        A list of corresponding weights that determine the likelihood of selecting each category.

    Returns
    -------
    any
        A randomly chosen category from `categories`, selected based on the given `weights`.

    Function Overview
    -----------------
    - Uses `random.choices()` to select one category from `categories`, considering the specified `weights`.
    - The `weights` list determines the probability of each category being chosen.
    - Calls `random.seed()` to ensure randomness is not influenced by previous runs.
    - Returns the selected category.
    '''
    
    random.seed()
    choice = random.choices(categories, weights)[0]
    return choice

# %%
def get_dob(age_range):
    """
    Generates a random date of birth (DOB) based on an age range category.

    Parameters
    ----------
    age_range: int
        An integer representing the age range category:
        - 0: 18-25 years old
        - 1: 26-35 years old
        - 2: 36-45 years old
        - 3: 46-60 years old
        - 4: 61+ years old

    Returns
    -------
    datetime.date
        A randomly generated date of birth within the specified age range.

    Raises
    ------
    ValueError
        If an invalid age range is provided.

    Function Overview
    -----------------
    - Uses the `Faker` library to generate a random birthdate within the given age range.
    - Supports five predefined age categories.
    - If an invalid `age_range` is given, raises a `ValueError`.
    """
    
    fake = Faker()
    match age_range:
        case 0:  # 18-25
            dob = fake.date_of_birth(minimum_age = 18, maximum_age=25)
            return dob
        case 1:  # 26-35
            dob = fake.date_of_birth(minimum_age = 26, maximum_age=35)
            return dob
        case 2:  # 36-45
            dob = fake.date_of_birth(minimum_age = 36, maximum_age=45)
            return dob
        case 3:  # 46-60
            dob = fake.date_of_birth(minimum_age = 46, maximum_age=60)
            return dob
        case 4:  # 60+
            dob = fake.date_of_birth(minimum_age = 61, maximum_age=112)
            return dob  # 112 is the age of the current oldest living person in Vancouver
        case _:  # Default case
            raise ValueError("Invalid age range")

# %%
def ethnicity_picker():
    """
    Randomly selects an ethnicity category based on predefined regional groups and weighted probabilities.

    Returns
    -------
    str
        A randomly chosen ethnicity from one of the predefined regional groups.

    Function Overview
    -----------------
    - Defines a list of ethnicity region categories, each represented by a predefined constant.
    - Assigns weighted probabilities to each category based on estimated distributions.
    - Uses `pick_demographics()` to randomly select an ethnicity group according to the weights.
    - Chooses a random ethnicity from the selected regional group.
    - Returns the randomly chosen ethnicity.
    """
    
    random.seed()
    indigenous = 0
    ethnicity_categories = [INDIGENOUS, MIDDLE_EASTERN_REGIONS, EUROPEAN_REGIONS, EAST_ASIAN_REGIONS, SOUTH_ASIAN_REGIONS, SOUTHEAST_ASIAN_REGIONS, LATIN_AMERICAN_REGIONS, AFRICAN_REGIONS, OTHER_REGIONS]
    ethnicity_weights = [0.0243, 0.0334, 0.4313, 0.2328, 0.1417, 0.0763, 0.0198, 0.0158, 0.0251]

    ethnicity_group = pick_demographics(ethnicity_categories, ethnicity_weights)
    print(ethnicity_group)
    
    if ethnicity_group == INDIGENOUS:
        indigenous = 1
    ethnicity = random.choice(ethnicity_group)
    return ethnicity, indigenous

# %%
def hydrate_patient_profile(variables, preset_attributes = {}) -> dict:
    """
    Generates a fully populated patient profile with demographic, medical, and personal details.

    Parameters
    ----------
    variables: dict
        A dictionary containing predefined patient variables.
    preset_attributes: dict, optional
        A dictionary of attributes that should be pre-set rather than generated. Defaults to an empty dictionary.

    Returns
    -------
    dict
        A patient profile dictionary containing structured demographic, medical, and personal history details.

    Function Overview
    -----------------
    - Randomly assigns ethnicity, sex, and name using `ethnicity_picker()` and `Faker()`.
    - Selects an age category and determines the corresponding date of birth (`get_dob()`).
    - Generates employment status, relationship status, and whether the patient has children based on age and marital status.
    - Determines handedness, address, and occupation.
    - Assigns a general practitioner or states "None" if no doctor is assigned.
    - Randomly selects allergies, medical conditions, and medications (`generate_health_conditions()`).
    - Determines substance use, past hospitalizations, head injuries, seizures, and family medical history.
    - Generates educational background and employment history based on age and disability status.
    - Assigns likelihood of past marriages/long-term relationships.
    - Adds hobbies, relaxation methods, and personality-related details (typing style, conversational tone).
    - Introduces optional "Do Not Disclose" scenarios for sensitive topics.
    - Adds potential edge case scenarios to test LLM robustness.
    - Returns the fully populated patient dictionary.

    Notes
    -----
    - Uses probability distributions and weights to ensure realism in assigned characteristics.
    - Ensures generated attributes are internally consistent (e.g., age aligns with education/work history).
    - Supports preset values in `preset_attributes` to maintain control over specific fields.
    """

    # Define multiple demographic categories
    gender_categories = [0, 1] # Male, Female
    gender_weights = [0.49, 0.51]

    age_categories = [0, 1, 2, 3, 4] # 18-25, 26-35, 36-45, 46-60, 60+
    age_weights_men = [0.2979, 0.1916, 0.1557, 0.2266, 0.1282]
    age_weights_women = [0.2861, 0.1683, 0.1483, 0.2343, 0.1630]
    
    random.seed()
    
    ethnicity, checker = ethnicity_picker()

    indigenous = checker
    
    fake_eth = Faker(ethnicity)
    patient = dict()
    print("Checker: ", indigenous)
    if indigenous == 1:
        print("indy")
        patient['Ethnicity Code'] = "en_Ind"
        patient["Ethnicity"] = "Indigenous"
    else: 
        print("not indy")
        patient['Ethnicity Code'] = ethnicity
        patient["Ethnicity"] = ETHNICITY_CODES.get(patient["Ethnicity Code"], "Unknown")
    
    #doctor data
    patient["Clinician Name"] = create_clinician_name()
    patient["Appointment Date"] = create_appt_date()
    
    #basic information
    sex = pick_demographics(gender_categories,gender_weights)
    middle_name = random.randint(0,1)
    
    if sex == 1:
        patient['Sex'] = "Female"
        try:
            patient['Full Name'] = fake_eth.name_female() 
        except Exception as g:
            print(f"Error generating female patient name: {g}")
            patient['Full Name'] = fake_eth.name_nonbinary()
            
        age_range = pick_demographics(age_categories, age_weights_women)
    else:
        try:
            patient['Sex'] = "Male"
            patient['Full Name'] = fake_eth.name_male()
        except Exception as g:
            print(f"Error generating male patient name: {g}")
            patient['Full Name'] = fake_eth.name_nonbinary()
            
        age_range = pick_demographics(age_categories, age_weights_men)
        
    fake = Faker()

    if "Age" not in patient.keys():
        dob = get_dob(age_range)
        patient['Age'] = relativedelta(datetime.now(), dob).years

        if random.random() <= 0.618: # employment rate
            job = fake.job()
        else:
            job = "unemployed"
        if patient['Age'] <= 22:
            job = "student " + job
        if patient['Age'] >= 75:
            job = "retired " + job

    if "Date of Birth" not in patient.keys():
        patient['Date of Birth'] =dob.strftime("%B %#d %Y") #windows: replace %-d with %#d

    # see document for calculation justifications, and sheets for performing calculations (?)
    relationship_status = [0,1,2,3,4] # single, LAT, married/common-law, divorced/separated, widowded
    relationship_weights = [
        [69.26, 23.09, 7.4, 0.25, 0.0],  # 18-25
        [31.73, 10.58, 55.35, 2.15, 0.2],  # 26-35
        [10.88, 3.63, 76.0, 8.15, 1.35],    # 36-45
        [9, 3, 68.33, 15.33, 8.17],   # 46-60
        [11.25, 3.75, 54.17, 8.83, 33.5]     # 60+
]
            
    if 'Relationship Status' not in patient.keys():
        if patient['Age'] <= 25:
            # print("PATIENT LESS THAN 25")
            relationship_int = pick_demographics(relationship_status, relationship_weights[0])
        elif patient['Age'] <= 35:
            # print("PATIENT LESS THAN 35")
            relationship_int = pick_demographics(relationship_status, relationship_weights[1])
        elif patient['Age'] <= 45:
            # print("PATIENT LESS THAN 45")
            relationship_int = pick_demographics(relationship_status, relationship_weights[2])
        elif patient['Age'] <= 60:
            # print("PATIENT LESS THAN 60")
            relationship_int = pick_demographics(relationship_status, relationship_weights[3])
        else:
            # print("PATIENT IS OLD")
            relationship_int = pick_demographics(relationship_status, relationship_weights[4])
            
        if relationship_int == 0:
            # print("SINGLE")
            patient['Relationship Status'] = "Single"
        elif relationship_int == 1:
            # print("LAT")
            patient['Relationship Status'] = "Long-term relationship"
        elif relationship_int == 2:
            # print("MARRIED")
            patient['Relationship Status'] = random.choice(["Married", "Common-Law"])
        elif relationship_int == 3:
            # print("DIV")
            patient['Relationship Status'] = random.choice(["Divorced", "Separated"])
        else:
            # print("WD")
            patient['Relationship Status'] = "Widowded"

    #https://open.canada.ca/data/en/dataset/5ae719d0-f4c7-4059-8c04-16886f9a5bbd families by age of eldest partner and # of children
    #https://open.canada.ca/data/en/dataset/ecdee020-5919-4996-8d3d-c3df75f50ca0 population estimate by age and gender

    in_family = [ # women, men
        [0.0756, 0.0701],    # 0-24
        [0.5102, 0.4765], # 25-34
        [0.8340, 0.8178], # 35-44
        [0.8426, 0.8557], # 45-54
        # [0.7444, 0.7622], # 55-64
        # [0.6873, 0.7995] # 65+
]
    w_children = [ # no, yes
        [0.6997, 0.3003],    # 0-24
        [0.5193, 0.4807], # 25-34
        [0.2056, 0.7944], # 35-44
        [0.1771, 0.8229], # 45-54
        # [0.4516, 0.5484], # 55-64
        # [0.7738, 0.2262] # 65+
]
    num_children = [ # 1, 2, 3
        [0.7440, 0.2016, 0.0546],    # 0-24
        [0.5057, 0.3338, 0.1605], # 25-34
        [0.3148, 0.4478, 0.2374], # 35-44
        [0.3592, 0.4346, 0.2062], # 45-54
        # [0.5692, 0.3216, 0.1092], # 55-64
        # [0.8212, 0.1485, 0.0303] # 65+
]
    if patient["Age"] < 25:
        age_idx = 0
    elif patient["Age"] < 35:
        age_idx = 1
    elif patient["Age"] < 45:
        age_idx = 2
    else:
        age_idx = 3 

    if sex == 0: # male
        in_fam = pick_demographics([1,0], [in_family[age_idx][1], 1-in_family[age_idx][1]])
    else: # female
        in_fam = pick_demographics([1,0], [in_family[age_idx][0], 1-in_family[age_idx][0]])

    if in_fam == 1:
        if 'Children' not in patient.keys() and 'Children Details' not in patient.keys():
            children = pick_demographics([0,1], w_children[age_idx])
        
            if children == 1:
                patient['Children'] = pick_demographics([1,2,3], num_children[age_idx])
                patient['Children Details'] = "{Children Details}"
            else:
                patient['Children'] = 0
    else:
        patient['Children'] = 0

    
    handedness_weights = [0.889, 0.058, 0.054]
    handedness_choices = ["right", "left", "ambidextrous"]
    if "Handedness" not in patient.keys():
        patient['Handedness'] = pick_demographics(handedness_choices, handedness_weights)
    
    # residence
    if "Address" not in patient.keys():
        patient['Address'] = f"{fake.street_address()}, {fake.city()}, British Columbia, Canada"
        
    # employment status
    if "Occupation" not in patient.keys():
        patient['Occupation'] = job
    
    # medical care information
    current_doctor_weights = [80, 20]
    current_doctor_options = ["Yes", "No"]
    if 'Current Doctors' not in patient.keys():
        if pick_demographics(current_doctor_options, current_doctor_weights) == "Yes":
            patient['Current Doctor(s)'] = f"Dr. {create_clinician_name()}, General Practioner"
        else:
            patient['Current Doctor(s)'] = "None"

    allergy_weights_f = [28.9, 100-28.9]
    allergy_weights_m = [25.6, 100-25.6]
    if "Allergies" not in patient.keys():
        if sex == 0: #male
            allergy = pick_demographics(["Yes", "No"], allergy_weights_m)
        else: #female
            allergy = pick_demographics(["Yes", "No"], allergy_weights_f)

        if allergy == "Yes":
            patient['Allergies'] = f"{', '.join(random.sample(COMMON_ALLERGIES, random.randint(1,3)))}"

    if "Medical Conditions" not in patient.keys() and "Medications" not in patient.keys():
        conditions, meds = generate_health_conditions(random.randint(1,3))
        patient['Medical Conditions'] = ", ".join(conditions)
        patient['Medications'] = ", ".join([f"{med_name} ({dosage})" for med_name, dosage in meds])
        
    if "Health Supplements" not in patient.keys():
        patient['Health Supplements'] = random.sample(COMMON_HEALTH_SUPPLEMENTS, random.randint(0,3))
        
    # substance use
    if 'Recreational Drug Usage' not in patient.keys():
        if random.random() <= 0.3:
            patient['Recreational Drug Usage'] = f'{", ".join(random.sample(["beer", "wine", "cannabis", "cigarettes", "shrooms", "psychedelics"], random.randint(1,4)))}'
            if "Rehab or Substance Counselling" not in patient.keys():
                patient["Rehab or Substance Counselling"] = "{Rehab or Substance Counselling}"
                
    # medical history
    if "Reason for Appointment" not in patient.keys():
        reasons = random.sample(DR_APPOINTMENT_REASONS, random.randint(1,3))
        patient["Reason for Appointment"] = ", ".join(reasons)

    if "Previous Hospitalizations or Surgeries" not in patient.keys():
        patient['Previous Hospitalizations or Surgeries'] = random.choice(["Yes", "No"])
        
        if patient['Previous Hospitalizations or Surgeries'] == "Yes":
            patient['Previous Hospitalizations or Surgeries Details'] = "{Previous Hospitalizations or Surgeries Details}"

    concussion_weights = [0.289, 1-0.289]
    if "Head Injuries or Concussions" not in patient.keys():
        patient['Head Injuries or Concussions'] = pick_demographics(["Yes", "No"], concussion_weights)
        
        if patient['Head Injuries or Concussions'] == "Yes":
            patient["Head Injuries or Concussions Details"] = "{Head Injuries or Concussions Details}"

    seizure_weights = [0.1, 0.9]
    if "History of Seizures" not in patient.keys():
        patient['History of Seizures'] = pick_demographics(["Yes", "No"], seizure_weights)
        
    
    # family history
    if "Family History of Health Conditions" not in patient.keys():
        patient['Family History of Health Conditions'] = random.choice(["Yes", "No"])
        
        if patient['Family History of Health Conditions'] == "Yes":
            patient['Family History of Health Conditions Details'] = "{Family History of Health Conditions Details}"

    siblings_weights = [0.40, 0.40, 0.15, 0.05]
    if 'Siblings' not in patient.keys() and 'Sibling Details' not in patient.keys():
        patient['Siblings'] = pick_demographics(["0", "1", "2", "3+"], siblings_weights)

        if patient['Siblings'] == "3+":
            patient['Siblings'] = random.choice(["3", "4", "5"])
        
        if not patient['Siblings'] == "0":
            patient['Sibling Details'] = "{Sibling Details}"
        
    # personal history
    canadian_weights = [0.912, 0.088] 
    if "Canadian Citizenship" not in patient.keys():
        patient['Canadian Citizenship'] = pick_demographics(["Yes", "No"], canadian_weights)

    if ethnicity == "fr_CA" or ethnicity == "en_CA":
        patient['Canadian Citizenship'] = "Yes"
    born_in_canada = ""
    if patient['Canadian Citizenship'] == "Yes":
        born_in_canada_weights = [53.1, 46.9]
        born_in_canada = pick_demographics(["Yes", "No"], born_in_canada_weights)
        
    if "Birthplace" not in patient.keys():
        if born_in_canada == "Yes":
            # print("CANADIAN")
            patient['Birthplace'] = f"{fake.city()}, Canada"
        else: 
            try:
                country = fake_eth.current_country()
                patient['Birthplace'] = f"{fake_eth.city()}, {country}"
            except Exception as c:
                print(f"Error generating current country for profile: {c}")
                country_code = fake_eth.current_country_code()
                patient['Birthplace'] = f"{fake_eth.city()}, {country_code}"


    disability_probability_total_w = [ # yes, no
        [0.247, 0.753], #18-24
        [0.269, 0.731], #25-64
        [0.418, 0.582]  # 65+
    ] 
    disability_probability_total_m = [ # yes, no
        [0.158, 0.842],
        [0.211, 0.789],
        [0.389, 0.611]
    ]

    # Determine age category index
    if patient['Age'] < 25:
        age_idx = 0
    elif patient['Age'] < 65:
        age_idx = 1
    else:
        age_idx = 2

    # Assigning probabilities based on sex
    sex_idx = 0 if patient['Sex'] == "Male" else 1  # Male = 0, Female = 1

    if 'Disabled' not in patient.keys():
        if age_idx == 0: # <25
            if sex_idx == 0: 
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_m[0])
            else:
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_w[0])
        if age_idx == 1 or age_idx == 2: # 25-64
            if sex_idx == 0:
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_m[1])
            else:
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_w[1])
        if age_idx == 3:
            if sex_idx == 0: # 65+
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_m[2])
            else:
                patient['Disabled'] = pick_demographics(["Yes", "No"], disability_probability_total_w[2])

    # https://www150.statcan.gc.ca/n1/pub/11-627-m/11-627-m2023063-eng.htm -- this is for all canadians, not just disabled ones
    # https://www150.statcan.gc.ca/n1/daily-quotidien/231201/dq231201b-eng.htm
    
    comorbidity_labels = [0, 1, 2] # only one, two or three, four (or more)
    
    comorbidity_num = [0.29, # only one
                         0.37, # two or three
                         0.34] # four (or more)
    comorbid_val = pick_demographics(comorbidity_labels, comorbidity_num)

    disability_list = ["Mental-health related", 
                       "Pain-related", "Seeing", 
                       "Learning", "Memory", 
                       "Mobility", "Flexibility", 
                       "Hearing", "Dexterity", 
                       "Developmental"]
    # Normalize the Dist (?)
    # https://www150.statcan.gc.ca/n1/daily-quotidien/231201/dq231201b-eng.htm

    # s = 38.6 + 61.8 + 27.4 + 20.7 + 18.2 + 39.2 + 40.3 + 20.7 + 18.4 + 5.7
    
    disability_probability_types = [38.6, 61.8, # Mental-health related, Pain-related
                                   27.4, 20.7, # Seeing, Learning
                                   18.2, 39.2, # Memory, Mobility
                                   40.3, 20.7, # Flexibilitiy, Hearing
                                   18.4, 5.7] # Dexterity, Developmental

    # Only assign mental disabilities **if the patient is already disabled**
    if patient['Disabled'] == "Yes":
        if comorbid_val == 0: #only one
            patient['Disability'] = pick_demographics(disability_list, disability_probability_types)

        else:
            patient['Disability'] = set()  # Using a set to ensure uniqueness

            if comorbid_val == 1:
                n = random.randint(2, 3)  # Randomly pick 2 or 3 disabilities
            else:
                n = 4  # Always pick 3 disabilities for comorbid_val > 1

            while len(patient['Disability']) < n:
                patient['Disability'].add(pick_demographics(disability_list, disability_probability_types))

            patient['Disability'] = list(patient['Disability'])  # Convert back to a list

        patient['Disability Details'] = "{Disability Details}"

    # https://inclusioncanada.ca/wp-content/uploads/2024/06/CDB-Vision-and-Design.pdf
    
    # Assign Disability Assistance (Only for disabled patients)
    if patient['Disabled'] == "Yes":
        disability_assistance_weights = [0.25, 0.75]  # 24.8%-28.4% of disabled people receive assistance
        if 'Disability Assistance' not in patient.keys():
            patient['Disability Assistance'] = pick_demographics(["Yes", "No"], disability_assistance_weights)

            if patient['Disability Assistance'] == "Yes":
                patient['Disability Assistance Details'] = "{Disability Assistance Details}"
    
    # education --
    # https://studentsuccess.gov.bc.ca/school-district/099/report/fsa
    # https://studentsuccess.gov.bc.ca/school-district/099/report/grad-assess

    # Adjusted probability distributions for elementary school performance
    elementary_school_weights = {
        "All Other": [0.266, 0.620, 0.114],  # Emerging, On Track, Extending
        "Indigenous": [0.508, 0.463, 0.029],
        "Disabilities or Diverse Abilities": [0.464, 0.444, 0.092]
    }

    # Probability distributions for high school performance
    # Dropout stats:
    # https://catalogue.data.gov.bc.ca/dataset/1c6256d0-c120-4de1-817b-fb291732f8a4/resource/2640bc34-d559-499d-b8a8-5dd0a0cbd823/download/completion_rate_residents_only_1999-2000_to_2023-2024.csv
    
    dropout_stats = [0.011, 0.244, 0.213] #All other, Indigenous, Disabilities or Diverse Abilities
    high_school_weights = {
        "All Other": [0.048, 0.232, 0.563, 0.157],  # Emerging, Developing, Proficient, Extending
        "Indigenous": [0.163, 0.389, 0.407, 0.041],
        "Disabilities or Diverse Abilities": [0.165, 0.360, 0.390, 0.085]
    }

    

    # Assign Categories
    if patient.get('Ethnicity') == "Indigenous":
        category = "Indigenous"
        dropout = pick_demographics(["Yes", "No"], [dropout_stats[1], 1-dropout_stats[1]])
    elif patient['Disabled'] == "Yes":
        category = "Disabilities or Diverse Abilities"
        dropout = pick_demographics(["Yes", "No"], [dropout_stats[2], 1-dropout_stats[2]])
    else:
        category = "All Other"
        dropout = pick_demographics(["Yes", "No"], [dropout_stats[0], 1-dropout_stats[0]])

    # Assign elementary school performance
    if "Elementary School Performance" not in patient.keys():
        patient["Elementary School Performance"] = pick_demographics(
            ["Emerging", "On Track", "Extending"], elementary_school_weights[category]
        )

    # Assign high school performance
    if "High School Performance" not in patient.keys():
        if dropout == "Yes":
            patient["High School Performance"] = "Drop out"
        else:
            patient["High School Performance"] = pick_demographics(["Emerging", "Developing", "Proficient", "Extending"], high_school_weights[category])

    # https://www12.statcan.gc.ca/census-recensement/2021/as-sa/fogs-spg/alternative.cfm?topic=11&lang=E&dguid=2021A00035915&objectId=4_2
    # Define education probabilities for 25-64 age group in Vancouver
    education_weights = [0.432, 0.273, 0.294]  # [Pursuing] University, [Pursuing] Post-Secondary (No Degree), No Further Education

    # only have stats for 25-64, applying to rest of ages due to lack of information
    
    if 25 <= patient['Age'] <= 64:
        patient['Further Education After Highschool'] = pick_demographics(
            ["University Degree", "Post-Secondary Certificate or Diploma", "No Further Education"],
            education_weights
        )
    elif 18 <= patient['Age'] < 25:
        patient['Further Education After Highschool'] = pick_demographics(
            ["Pursuing University Degree", "Pursuing Post-Secondary Certificate or Diploma", "No Further Education"],
        education_weights
        )
    else:
        patient['Further Education After Highschool'] = "Unknown"  # In case of error

        
    # previous employment and relationships
    # https://www12.statcan.gc.ca/census-recensement/2021/as-sa/fogs-spg/page.cfm?topic=12&lang=E&dguid=2021S0503933

    # Define probability of having previous work history by age
    work_history_weights = {
        "18-24": [0.479, 1-0.479],  
        "25-64": [0.756, 1-0.756],  
        "65+": [0.756, 1-0.756]  # same as 25-64 due to lack of statistics
    }

    # Determine correct probability
    if patient['Age'] < 25:
        work_weights = work_history_weights["18-24"]
    elif patient['Age'] < 65:
        work_weights = work_history_weights["25-64"]
    else:
        work_weights = work_history_weights["65+"]

    # Assign work history based on probabilities
    if "Previous Work History" not in patient.keys():
        patient["Previous Work History"] = pick_demographics(
            ["Has Work History", "No Work History"], work_weights
        )

        if patient["Previous Work History"] == "Has Work History":
            patient["Previous Work History"] = "{Previous Work History}"

    # Define probability of having previous marriages/relationships by age
    # https://www12.statcan.gc.ca/census-recensement/2021/as-sa/fogs-spg/alternative.cfm?topic=4&lang=E&dguid=2021S0503933&objectId=6
    # relationship_history_weights = {
    #     "18-24": [0.15, 0.85],  # Low likelihood of past relationships
    #     "25-34": [0.35, 0.65],  # Increasing likelihood
    #     "35-64": [0.60, 0.40],  # Most likely have had a prior relationship
    #     "65+": [0.80, 0.20]  # Majority have had at least one past relationship
    # }

    # lack of avaliable data
    relationship_history_weights = [1-0.306, 0.306]

    relationship_weights = relationship_history_weights
    # Determine correct probability
    # if patient['Age'] < 25:
    #     relationship_weights = relationship_history_weights["18-24"]
    # elif patient['Age'] < 35:
    #     relationship_weights = relationship_history_weights["25-34"]
    # elif patient['Age'] < 65:
    #     relationship_weights = relationship_history_weights["35-64"]
    # else:
    #     relationship_weights = relationship_history_weights["65+"]
    
    # Assign relationship history based on probabilities
    if "Previous Marriages/Long-Term Relationships" not in patient.keys():
        patient["Previous Marriages/Long-Term Relationships"] = pick_demographics(
            ["Has Previous Relationships/Marriages", "No Previous Relationships"], 
            relationship_weights
        )
        if patient["Previous Marriages/Long-Term Relationships"] == "Has Previous Relationships/Marriages":
            patient["Previous Marriages/Long-Term Relationships"] = "{Previous Marriages/Long-Term Relationships}"


    # hobbies and lifestyle
    if "Hobbies" not in patient.keys():
        patient["Hobbies"] = "{Hobbies}"
    if "Relaxation Methods" not in patient.keys():
        patient["Relaxation Methods"] = "{Relaxation Methods}"

    # attributes with possible do not disclose options
    dnd_attributes = [
        "Past Trauma", 
        "Substance Abuse", 
    ]

    for attribute in dnd_attributes:
        if attribute not in patient.keys():
            cond = random.random() #returns [0,1)
            if cond <= 0.5: patient[attribute] = "yes"
            else: patient[attribute] = "None"
    
    # create variation in conversations and tones
    if "Typing Style" not in patient.keys():
        patient["Typing Style"] = random.choice(TYPING_STYLES)
    if "Conversational Tone" not in patient.keys():
        patient["Conversational Tone"] = random.choice(CONVERSATIONAL_TONE)
    if "Personality Traits" not in patient.keys():
        patient["Personality Traits"] = random.sample(PERSONALITY_TRAITS, random.randint(1,4))
    if "Edge Case Scenario" not in patient.keys():
        cond = random.random() #returns [0,1)
        if cond <= 0.5: patient["Edge Case Scenario"] = random.choice(EDGE_CASE_SCENARIOS)
        else: patient[attribute] = "N/A"
        
    print("Patient Dict - BEFORE LLM", patient)
    return patient

# %%
def clean_stars_from_dict(patient_dict):
    '''
    Cleans leading '** ' and surrounding spaces from string values in a patient dictionary.

    Parameters
    ----------
    patient_dict: dict
        A dictionary containing patient information.

    Returns
    -------
    dict
        The cleaned dictionary with unnecessary formatting removed from string values.

    Function Overview
    -----------------
    - Iterates over the dictionary and checks if each value is a string.
    - Removes any leading '** ' and surrounding spaces from string values.
    - Returns the updated dictionary.
    '''
    for key, value in patient_dict.items():
        if isinstance(value, str):  # Only clean string values
            patient_dict[key] = value.lstrip('** ').strip()  # Remove leading '** ' and any surrounding spaces
    return patient_dict

# Function to update the dictionary with LLM output using flexible pattern matching
def hydrate_dict(patient_dict, llm_output):
    '''
    Updates a patient dictionary with details extracted from LLM-generated output using pattern matching.

    Parameters
    ----------
    patient_dict: dict
        A dictionary containing patient information, potentially with missing or placeholder values.
    llm_output: str
        The text output generated by the LLM, containing new details to populate missing fields.

    Returns
    -------
    dict
        The updated patient dictionary with extracted values inserted into their respective fields.

    Function Overview
    -----------------
    - Defines regex patterns to extract key details (e.g., Anglicized names, medical history, family details) from `llm_output`.
    - Iterates through each pattern, searching for matches in `llm_output`.
    - Updates `patient_dict` with extracted values if a match is found.
    - Calls `clean_stars_from_dict()` to remove formatting artifacts from string values.
    - Returns the updated dictionary with hydrated fields.
    '''
    
    # Define patterns to capture various fields in the LLM output
    patterns = {
        'Full Name': r"Anglicized Full Name[:\s]*([^\n]+)",
        'Birthplace': r"Anglicized Birthplace[:\s]*([^\n]+)",
        'Clinician Name': r"Anglicized Clinician Name[:\s]*([^\n]+)",
        'Current Doctor(s)': r"Anglicized Doctor Name[:\s]*([^\n]+)",
        'Children Details' : r"Children Details[:\s]*([^\n]+)",
        'Disability Assistance Details': r"Disability Assistance Details[:\s]*([^\n]+)",
        'Disability Details': r"Disability Details[:\s]*([^\n]+)",
        'Previous Hospitalizations or Surgeries Details' : r"Previous Hospitalizations or Surgeries Details[:\s]*([^\n]+)",
        'Head Injuries or Concussions Details' : r"Head Injuries or Concussions Details[:\s]*([^\n]+)",
        'Rehab or Substance Counselling': r"Rehab or Substance Counselling[:\s]*([^\n]+)",
        'Family History of Health Conditions Details': r"Family History of Health Conditions Details[:\s]*([^\n]+)",
        'Sibling Details': r"Sibling Details[:\s]*([^\n]+)",
        'Previous Work History': r"Previous Work History[:\s]*([^\n]+)",
        'Previous Marriages/Long-Term Relationships': r"Previous Marriages/Long-Term Relationships[:\s]*([^\n]+)",
        'Hobbies': r"Hobbies[:\s]*([^\n]+)",
        'Relaxation Methods': r"Relaxation Methods[:\s]*([^\n]+)"
    }

    # Loop through each pattern and search for matches in the LLM output
    for key, pattern in patterns.items():
        match = re.search(pattern, llm_output, re.IGNORECASE)
        if match:
            patient_dict[key] = match.group(1).strip()  # Update dict with captured value
    
    clean_stars_from_dict(patient_dict)
    return patient_dict

# %%
def patient_to_csv(patient:dict, filepath:str="./llm_patients.csv"):
    '''
    Saves or appends a patient dictionary to a CSV file.

    Parameters
    ----------
    patient: dict 
        A dictionary containing patient details.
    filepath: str, optional
        The filepath for the CSV file where patient data will be stored. Defaults to "./llm_patients.csv".

    Function Overview
    -----------------
    - Attempts to read an existing CSV file at `filepath` using pandas (`pd.read_csv()`).
    - If the file exists:
      - Converts the existing data into a dictionary (`current_dict`).
      - Ensures all columns in the existing CSV are included in the new patient entry.
      - Appends the new patient data to the existing structure.
      - Saves the updated data back to the CSV file.
    - If the file does not exist:
      - Creates a new CSV file with `patient` as the first entry.
    - Uses `|` as the delimiter to prevent issues with commas in text fields.
    '''
    try:
        current_df = pd.read_csv(filepath, sep="|")
        current_dict = current_df.to_dict("list")
        existing_len = current_df.shape[0]
        
        #add variables in current dict not in patient dict
        missing_cols = list(set(list(current_dict.keys())) - set(list(patient.keys())))
        for missing_col in missing_cols:
            patient[missing_col] = ""
        
        #add everything from patient dict to to the current dict
        for col in patient.keys():
            if col in current_dict:
                current_dict[col].append(patient[col])
            else:
                #create a new column for variable in patient dict not in current dict
                buffer = [""]*existing_len
                buffer.append(patient[col])
                current_dict[col] = buffer

        updated_df = pd.DataFrame(current_dict)

    except FileNotFoundError:
        print(f"creating file at {filepath}")
        updated_dict = {}
        #save dictionary as csv with keys
        for col in patient.keys():
            updated_dict[col] = [f"{patient[col]}"]
        updated_df = pd.DataFrame(updated_dict)

    updated_df.to_csv(filepath, sep="|",index=False)

def patient_creator(filepath = "./llm_patients.csv"):
    """
    Generates a randomized patient profile and adds it to a CSV file.

    Parameters
    ----------
    filepath: str, optional
        The filepath for the CSV file where patient data will be stored. Defaults to "./llm_patients.csv".

    Returns
    -------
    dict
        The generated patient dictionary.

    Function Overview
    -----------------
    - Calls `generate_patient_profile(variables)` to create a randomized patient profile.
    - Saves the generated patient profile to a CSV file using `patient_to_csv()`.
    - Returns the generated patient dictionary.
    """
    
    patient = generate_patient_profile(variables)
    patient_to_csv(patient, filepath)
    return patient

# %%
i=0
while i < 818:
    patient_creator(filepath="../llm_patients_043025.csv")
    i += 1
    print(i)
# patient_creator(filepath="../llm_patients.csv")
# 1000 patients - 3:09:24
# Out:
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'zh_CN', 'Ethnicity': 'Chinese - China', 'Clinician Name': 'Mathilde Schou-Thygesen', 'Appointment Date': 'September 25', 'Sex': 'Male', 'Full Name': '李静', 'Age': 37, 'Date of Birth': 'November 23 1987', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '7561 Kathy Turnpike, Randytown, British Columbia, Canada', 'Occupation': 'unemployed', 'Current Doctor(s)': 'Dr. Eva Crivelli, General Practioner', 'Medical Conditions': 'generalized anxiety disorder, narcissistic personality disorder', 'Medications': '', 'Health Supplements': ['multivitamins'], 'Recreational Drug Usage': 'cigarettes, psychedelics', 'Rehab or Substance Counselling': '{Rehab or Substance Counselling}', 'Reason for Appointment': 'excessive preoccupation with body image or weight, severe and persistent anxiety', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'North Micheleland, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Developing', 'Further Education After Highschool': 'University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'None', 'Substance Abuse': 'N/A', 'Typing Style': 'formal', 'Conversational Tone': 'sad', 'Personality Traits': ['Selfish']}
# Rehab or Substance Counselling: {Rehab or Substance Counselling}, Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Rehab or Substance Counselling: Attended a 6-week outpatient substance abuse program at the British Columbia Addiction Centre in 2015
# Previous Hospitalizations or Surgeries Details: Hospitalized for 3 days in 2012 for a psychotic episode related to psychedelic use, and underwent an appendectomy in 2008
# Family History of Health Conditions Details: Mother has a history of depression, father has a history of hypertension, and maternal grandmother was diagnosed with schizophrenia
# Sibling Details: Has one older sister, aged 40, who works as a psychologist and has been a source of emotional support
# Previous Work History: Worked as a freelance graphic designer from 2010 to 2015, then as a sales associate at a clothing store from 2015 to 2018
# Hobbies: Enjoys photography, playing guitar, and writing poetry
# Relaxation Methods: Practices deep breathing exercises, meditation, and yoga to manage anxiety
# Anglicized Full name: Li Jing
# Anglicized Clinician Name: Mathilde Schou-Thygesen
# Anglicized Birthplace: North Micheleland, Canada
# Anglicized Doctor Name: Dr. Eva Crivelli
# 1
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Checker:  0
# not indy
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'bn_BD', 'Ethnicity': 'Bengali - Bangladesh', 'Clinician Name': '橋本 明美', 'Appointment Date': 'September 05', 'Sex': 'Male', 'Full Name': 'নয়ন যাদব', 'Age': 23, 'Date of Birth': 'May 22 2001', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '93702 Lisa Station, Lake Kennethmouth, British Columbia, Canada', 'Occupation': 'unemployed', 'Current Doctor(s)': 'Dr. Нестерова Зоя Аскольдовна, General Practioner', 'Medical Conditions': 'generalized anxiety disorder', 'Medications': 'Duloxetine (Cymbalta) (60-120 mg/day)', 'Health Supplements': ['sports nutrition supplements'], 'Reason for Appointment': 'extreme mood swings, delusions (false beliefs not based in reality)', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '0', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Trevorhaven, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'Pursuing University Degree', 'Previous Work History': 'No Work History', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'None', 'Typing Style': 'informal', 'Conversational Tone': 'hyperactive', 'Personality Traits': ['Empathetic'], 'Edge Case Scenario': 'When asked about medication, mention only the color or shape of the pills instead of the name. Only provide the name if directly asked.'}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: In 2018, the patient was hospitalized for a week due to severe anxiety attacks and in 2020, he underwent surgery for an appendectomy.
# Family History of Health Conditions Details: The patient's mother has been diagnosed with depression, and his father has high blood pressure.
# Hobbies: Reading fantasy novels, playing video games, and hiking.
# Relaxation Methods: Listening to classical music, practicing yoga, and taking long walks in nature.
# Anglicized Full name: Nayan Yadav
# Anglicized Clinician Name: Akimi Hashimoto
# Anglicized Birthplace: Trevorhaven, Canada
# Anglicized Doctor Name: Dr. Zoya Askoldovna Nestrova
# 2
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Checker:  0
# not indy
# ['en_MS', 'en_PH', 'fil_PH', 'id_ID', 'th_TH', 'tl_PH', 'vi_VN']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'az_AZ', 'Ethnicity': 'Azerbaijani - Azerbaijan', 'Clinician Name': 'Elizabeth Smith', 'Appointment Date': 'February 07', 'Sex': 'Female', 'Full Name': 'Səriyyə Məmmədxanlı', 'Age': 21, 'Date of Birth': 'January 30 2004', 'Relationship Status': 'Long-term relationship', 'Children': 0, 'Handedness': 'right', 'Address': '1790 Rodriguez Dam, Luisshire, British Columbia, Canada', 'Occupation': 'student unemployed', 'Current Doctor(s)': 'Dr. Dina Zito, General Practioner', 'Medical Conditions': 'avoidant personality disorder, antisocial personality disorder, obsessive-compulsive disorder', 'Medications': 'Sertraline (Zoloft) (50 mg/day), Paroxetine (Paxil) (40-60 mg/day)', 'Health Supplements': ['multivitamins', 'herbal supplements'], 'Recreational Drug Usage': 'cigarettes, beer, psychedelics, wine', 'Rehab or Substance Counselling': '{Rehab or Substance Counselling}', 'Reason for Appointment': 'manic or hypomanic episodes, loss of touch with reality', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Bakı, Azerbaijan', 'Disabled': 'No', 'Elementary School Performance': 'Extending', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'No Further Education', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'informal', 'Conversational Tone': 'nervous', 'Personality Traits': ['Cruel', 'Impatient', 'Generous']}
# Rehab or Substance Counselling: {Rehab or Substance Counselling}, Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Rehab or Substance Counselling: attended a 6-week substance abuse program at the local community center
# Previous Hospitalizations or Surgeries Details: hospitalized twice for psychotic episodes and once for a minor surgery to remove a cyst on her wrist
# Sibling Details: has an older brother named Emil Məmmədxanlı, who is currently studying abroad in Turkey
# Previous Work History: worked part-time as a barista at a local café for 8 months before quitting due to anxiety issues
# Previous Marriages/Long-Term Relationships: currently in a long-term relationship with her boyfriend, previously had a 2-year relationship that ended due to trust issues
# Hobbies: enjoys painting, playing the guitar, and writing poetry
# Relaxation Methods: practices deep breathing exercises, meditation, and yoga to manage stress and anxiety
# Anglicized Full name: Sariya Mammadkhanli
# Anglicized Clinician Name: Elizabeth Smith
# Anglicized Birthplace: Baku, Azerbaijan
# Anglicized Doctor Name: Dr. Dina Zito
# 3
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'ko_KR', 'Ethnicity': 'Korean - South Korea', 'Clinician Name': '吴慧', 'Appointment Date': 'January 04', 'Sex': 'Female', 'Full Name': '최예진', 'Age': 58, 'Date of Birth': 'May 17 1966', 'Relationship Status': 'Married', 'Children': 3, 'Children Details': '{Children Details}', 'Handedness': 'right', 'Address': '641 Crystal Ports, West Destinyhaven, British Columbia, Canada', 'Occupation': 'Arts development officer', 'Current Doctor(s)': 'Dr. Ακριβός-Στέλλιος Σταμάτης, General Practioner', 'Medical Conditions': 'social anxiety disorder', 'Medications': 'Paroxetine (Paxil) (10 mg/day)', 'Health Supplements': ['probiotics', 'vitamin D'], 'Recreational Drug Usage': 'wine, shrooms, beer', 'Rehab or Substance Counselling': '{Rehab or Substance Counselling}', 'Reason for Appointment': 'significant changes in personality or behavior', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '5', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Jessicafort, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'No Further Education', 'Previous Work History': 'No Work History', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'None', 'Substance Abuse': 'N/A', 'Typing Style': 'formal', 'Conversational Tone': 'nervous', 'Personality Traits': ['Impulsive']}
# Children Details: {Children Details}, Rehab or Substance Counselling: {Rehab or Substance Counselling}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Children Details: Three children, two boys and one girl, ages 25, 22, and 19, all living at home except the eldest who is away at university
# Rehab or Substance Counselling: No history of rehab or substance counselling, but has considered seeking help for social anxiety disorder
# Family History of Health Conditions Details: Mother had hypertension, father had type 2 diabetes, older brother has bipolar disorder, and younger sister has asthma
# Sibling Details: Five siblings, three brothers and two sisters, with ages ranging from 45 to 61, all living in different parts of Canada except one brother who lives in the United States
# Hobbies: Painting, gardening, reading Korean literature, and playing the gayageum
# Relaxation Methods: Listening to traditional Korean music, practicing yoga, taking short walks in nature, and meditating
# Anglicized Full name: Choi Ye-jin
# Anglicized Clinician Name: Wu Hui
# Anglicized Birthplace: Jessicafort, Canada
# Anglicized Doctor Name: Dr. Akribos-Stelios Stamatios
# 4
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_BD', 'Ethnicity': 'English - Bangladesh', 'Clinician Name': 'Britt-Marie Larsson', 'Appointment Date': 'September 17', 'Sex': 'Female', 'Full Name': 'Julia Horton', 'Age': 19, 'Date of Birth': 'July 04 2005', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '2811 Elizabeth Coves, West Elainehaven, British Columbia, Canada', 'Occupation': 'student Music therapist', 'Current Doctor(s)': 'Dr. आदरसूचक रामचन्द्र पवार, General Practioner', 'Medical Conditions': 'generalized anxiety disorder, binge-eating disorder, social anxiety disorder', 'Medications': 'Duloxetine (Cymbalta) (30 mg/day), Topiramate (Topamax) (100-400 mg/day), Sertraline (Zoloft) (50-200 mg/day)', 'Health Supplements': ['iron'], 'Reason for Appointment': 'manic or hypomanic episodes, unexplained or excessive guilt', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'Yes', 'Family History of Health Conditions': 'No', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Mymensingh, Bangladesh', 'Disabled': 'Yes', 'Disability': 'Seeing', 'Disability Details': '{Disability Details}', 'Disability Assistance': 'Yes', 'Disability Assistance Details': '{Disability Assistance Details}', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Drop out', 'Further Education After Highschool': 'Pursuing Post-Secondary Certificate or Diploma', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'None', 'Typing Style': 'brief', 'Conversational Tone': 'nervous', 'Personality Traits': ['Optimistic', 'Closed-minded', 'Cautious', 'Humble'], 'Edge Case Scenario': "When asked about high school, discuss social experiences instead of grades or classes, e.g., 'I mostly remember hanging out with friends."}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Sibling Details: {Sibling Details}, Disability Details: {Disability Details}, Disability Assistance Details: {Disability Assistance Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: Hospitalized twice for anxiety disorder episodes, once in 2020 for a week and again in 2022 for three weeks, both times at the local hospital in West Elainehaven.
# Sibling Details: One younger brother named Ethan Horton, age 14, who is still in high school and lives with their parents.
# Disability Details: Julia has limited vision due to an eye condition that was diagnosed at a young age, which affects her daily life but does not completely impair her ability to see.
# Disability Assistance Details: Uses a guide dog named Max for mobility assistance, receives regular check-ups from a low-vision specialist, and utilizes assistive technology such as screen readers on her devices.
# Previous Work History: Volunteer music therapist at the local community center for six months before pursuing post-secondary education, also worked part-time as a server at a restaurant near her home for about a year.
# Hobbies: Enjoys playing the guitar, writing poetry, and practicing yoga in her free time.
# Relaxation Methods: Listens to calming music, practices deep breathing exercises, and goes for short walks around her neighborhood when feeling overwhelmed.
# Anglicized Full name: Julia Horton
# Anglicized Clinician Name: Britt-Marie Larsson
# Anglicized Birthplace: Mymensingh, Bangladesh
# Anglicized Doctor Name: Dr. Adarsuchak Ramchandra Pawar
# 5
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# ['en_MS', 'en_PH', 'fil_PH', 'id_ID', 'th_TH', 'tl_PH', 'vi_VN']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_CA', 'Ethnicity': 'English - Canada', 'Clinician Name': 'Lucila Tello-Cabrera', 'Appointment Date': 'June 15', 'Sex': 'Male', 'Full Name': 'Brian Bryant', 'Age': 22, 'Date of Birth': 'June 14 2002', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'ambidextrous', 'Address': '63053 Briggs Lane Apt. 207, New Patrickmouth, British Columbia, Canada', 'Occupation': 'student Surveyor, insurance', 'Current Doctor(s)': 'Dr. Nhật Hoàng, General Practioner', 'Medical Conditions': 'generalized anxiety disorder, panic disorder', 'Medications': 'Escitalopram (Lexapro) (10 mg/day), Alprazolam (Xanax) (1-4 mg/day (divided doses))', 'Health Supplements': [], 'Reason for Appointment': 'severe and persistent anxiety, significant changes in personality or behavior', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Jenkinsmouth, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Extending', 'Further Education After Highschool': 'Pursuing Post-Secondary Certificate or Diploma', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'informal', 'Conversational Tone': 'hyperactive', 'Personality Traits': ['Selfish', 'Lazy', 'Analytical', 'Arrogant']}
# Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Family History of Health Conditions Details: Mother has hypertension and father has a history of depression
# Sibling Details: One younger sister, age 19, currently attending college
# Previous Work History: Part-time landscaping job during high school and summer internship at an insurance company
# Previous Marriages/Long-Term Relationships: None
# Hobbies: Playing guitar, hiking, and reading science fiction novels
# Relaxation Methods: Meditation, deep breathing exercises, and listening to classical music
# Anglicized Full name: Brian Bryant
# Anglicized Clinician Name: Lucila Tello-Cabrera
# Anglicized Birthplace: Jenkinsmouth, Canada
# Anglicized Doctor Name: Dr. Nhat Hoang
# 6
# ['es_AR', 'es_CL', 'es_CO', 'es_MX', 'pt_BR']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'es_MX', 'Ethnicity': 'Spanish - Mexico', 'Clinician Name': 'Elin Johansson', 'Appointment Date': 'January 19', 'Sex': 'Female', 'Full Name': 'Aldonza Garibay Valadez', 'Age': 21, 'Date of Birth': 'February 17 2004', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '689 Craig Spur Suite 697, Josephstad, British Columbia, Canada', 'Occupation': 'student unemployed', 'Current Doctor(s)': 'None', 'Medical Conditions': 'borderline personality disorder, social anxiety disorder, generalized anxiety disorder', 'Medications': 'Sertraline (Zoloft) (50-200 mg/day), Duloxetine (Cymbalta) (30 mg/day)', 'Health Supplements': ['fish oil supplements', 'calcium', 'iron'], 'Reason for Appointment': 'significant decline in school or work performance, inability to perform daily activities or take care of oneself, difficulty managing life transitions or stressors', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '2', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'South Kelliside, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Developing', 'Further Education After Highschool': 'Pursuing Post-Secondary Certificate or Diploma', 'Previous Work History': 'No Work History', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'formal', 'Conversational Tone': 'hyperactive', 'Personality Traits': ['Irresponsible', 'Impatient', 'Patient']}
# Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Family History of Health Conditions Details: Mother was diagnosed with depression, father has a history of substance abuse, and maternal grandmother had anxiety disorder
# Sibling Details: Older sister, 25, works as an accountant and is married with one child, younger brother, 19, currently in high school
# Previous Marriages/Long-Term Relationships: No previous marriages, had one long-term relationship that ended two years ago due to emotional abuse
# Hobbies: Painting, reading fiction novels, playing guitar, and hiking
# Relaxation Methods: Meditation, deep breathing exercises, listening to classical music, and taking warm baths
# Anglicized Full name: Aldonza Garibay Valadez
# Anglicized Clinician Name: Elin Johansson
# Anglicized Birthplace: South Kelliside, Canada
# Anglicized Doctor Name: None
# 7
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Checker:  0
# not indy
# ['fa_IR', 'he_IL']
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'de_DE', 'Ethnicity': 'German - Germany', 'Clinician Name': 'آرمين فرجی', 'Appointment Date': 'September 08', 'Sex': 'Male', 'Full Name': 'Heinrich Kabus', 'Age': 18, 'Date of Birth': 'April 12 2007', 'Relationship Status': 'Long-term relationship', 'Children': 0, 'Handedness': 'right', 'Address': '5685 Timothy Junctions Apt. 779, Gainesmouth, British Columbia, Canada', 'Occupation': 'student unemployed', 'Current Doctor(s)': 'Dr. 中村 陽一, General Practioner', 'Medical Conditions': 'post-traumatic stress disorder', 'Medications': 'Fluoxetine (Prozac) (10-20 mg/day)', 'Health Supplements': ['iron'], 'Reason for Appointment': 'extreme mood swings, severe and persistent insomnia or hypersomnia, disrupted thought patterns or speech', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'North Thomasborough, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'Pursuing University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'None', 'Typing Style': 'formal', 'Conversational Tone': 'nervous', 'Personality Traits': ['Selfish', 'Adventurous'], 'Edge Case Scenario': "When asked about high school, discuss social experiences instead of grades or classes, e.g., 'I mostly remember hanging out with friends."}
# Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Family History of Health Conditions Details: Mother diagnosed with depression, father has a history of anxiety disorder
# Sibling Details: One younger sister, age 15, no known health conditions
# Previous Work History: Part-time job as a library assistant during high school, currently unemployed due to university studies
# Hobbies: Playing guitar, reading fantasy novels, and hiking
# Relaxation Methods: Listening to classical music, meditation, and taking short walks
# Anglicized Full name: Heinrich Kabus
# Anglicized Clinician Name: Armin Faraji
# Anglicized Birthplace: North Thomasborough, Canada
# Anglicized Doctor Name: Dr. Nakamura Yoichi
# 8
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'zh_CN', 'Ethnicity': 'Chinese - China', 'Clinician Name': 'Περικλής-Κομνηνός Σαλίχος', 'Appointment Date': 'May 21', 'Sex': 'Male', 'Full Name': '汪桂英', 'Age': 21, 'Date of Birth': 'March 01 2004', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '8419 Singh Park Apt. 188, North James, British Columbia, Canada', 'Occupation': 'student unemployed', 'Current Doctor(s)': 'None', 'Medical Conditions': 'anorexia', 'Medications': 'Sertraline (Zoloft) (50-200 mg/day)', 'Health Supplements': ['iron'], 'Reason for Appointment': 'panic attacks, thoughts of self-harm or suicide', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'Yes', 'Family History of Health Conditions': 'No', 'Siblings': '0', 'Canadian Citizenship': 'No', 'Birthplace': "澳门市, People's Republic of China", 'Disabled': 'No', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'Pursuing Post-Secondary Certificate or Diploma', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'None', 'Typing Style': 'rambling', 'Conversational Tone': 'sad', 'Personality Traits': ['Loyal', 'Patient'], 'Edge Case Scenario': "When asked about hobbies, respond with something general like 'I stay busy' and elaborate only if the interviewer asks for specifics."}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: Hospitalized twice for anorexia complications and once for a seizure episode, with the most recent hospitalization occurring 6 months ago at Vancouver General Hospital.
# Previous Work History: Worked part-time as a library assistant for 1 year during high school and briefly interned at a local marketing firm before focusing on studies.
# Hobbies: I stay busy with reading, writing, and drawing, often finding solace in creative activities to manage stress and emotions.
# Relaxation Methods: Listening to calming music, practicing deep breathing exercises, and taking short walks outdoors help me unwind and relax.
# Anglicized Full name: Wang Guiying
# Anglicized Clinician Name: Pericles-Komnenos Salichos
# Anglicized Birthplace: Macau City, People's Republic of China
# Anglicized Doctor Name: None
# 9
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_BD', 'Ethnicity': 'English - Bangladesh', 'Clinician Name': 'Luise Freudenberger', 'Appointment Date': 'October 19', 'Sex': 'Male', 'Full Name': 'Samuel Espinoza', 'Age': 49, 'Date of Birth': 'January 26 1976', 'Relationship Status': 'Common-Law', 'Children': 3, 'Children Details': '{Children Details}', 'Handedness': 'right', 'Address': '710 Valerie Lock, Bradshawhaven, British Columbia, Canada', 'Occupation': 'Contractor', 'Current Doctor(s)': 'None', 'Medical Conditions': 'avoidant personality disorder, anorexia', 'Medications': 'Sertraline (Zoloft) (50-200 mg/day), Olanzapine (Zyprexa) (2.5-5 mg/day)', 'Health Supplements': [], 'Recreational Drug Usage': 'cannabis, psychedelics, cigarettes, beer', 'Rehab or Substance Counselling': '{Rehab or Substance Counselling}', 'Reason for Appointment': 'loss of touch with reality', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '0', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Sullivanview, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Extending', 'Further Education After Highschool': 'University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'rambling', 'Conversational Tone': 'sad', 'Personality Traits': ['Unimaginative', 'Kind', 'Cold-hearted']}
# Children Details: {Children Details}, Rehab or Substance Counselling: {Rehab or Substance Counselling}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Children Details: Three children, two boys and one girl, aged 10, 12, and 15, all living with their mother due to Samuel's current mental health struggles.
# Rehab or Substance Counselling: Attended a 6-week substance abuse program in 2018 for cannabis and psychedelic use, but did not complete the follow-up counseling sessions.
# Previous Work History: Worked as a carpenter from 2005-2010, then started his own contracting business which he ran until 2015 when he had to file for bankruptcy due to financial difficulties.
# Previous Marriages/Long-Term Relationships: Was previously married from 2002-2008 and has been in his current common-law relationship since 2012.
# Hobbies: Enjoys woodworking, reading science fiction novels, and playing guitar in his free time.
# Relaxation Methods: Practices meditation and deep breathing exercises to manage stress and anxiety, but has been struggling to maintain a consistent practice due to his avoidant personality disorder.
# Anglicized Full name: Samuel Espinoza
# Anglicized Clinician Name: Luise Freudenberger
# Anglicized Birthplace: Sullivanview, Canada
# Anglicized Doctor Name: None
# 10
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Checker:  0
# not indy
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'de_CH', 'Ethnicity': 'German - Switzerland', 'Clinician Name': '蕭中山', 'Appointment Date': 'April 24', 'Sex': 'Male', 'Full Name': 'Lia Schär', 'Age': 89, 'Date of Birth': 'March 09 1936', 'Relationship Status': 'Married', 'Children': 0, 'Handedness': 'right', 'Address': '81323 Stephanie Union Apt. 218, Melissachester, British Columbia, Canada', 'Occupation': 'retired Ergonomist', 'Current Doctor(s)': 'Dr. pani Marcelina Dudczak, General Practioner', 'Medical Conditions': 'obsessive-compulsive disorder', 'Medications': '', 'Health Supplements': ['herbal supplements', 'multivitamins', 'melatonin'], 'Reason for Appointment': 'extreme mood swings, disorganized thinking or speech', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '0', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Wettingen, Switzerland', 'Disabled': 'No', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Extending', 'Further Education After Highschool': 'Unknown', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'None', 'Substance Abuse': 'yes', 'Typing Style': 'informal', 'Conversational Tone': 'hyperactive', 'Personality Traits': ['Unreliable'], 'Edge Case Scenario': 'Mention using one substance (e.g., alcohol) but omit other substances you use until explicitly asked.'}
# Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Anglicized Full name: Lia Shar
# Anglicized Clinician Name: Xiao Zhongshan
# Anglicized Birthplace: Wettingen, Switzerland
# Anglicized Doctor Name: Dr. Pani Marcelina Dudczak
# Previous Work History: Worked as an Ergonomist for 30 years at a private firm in British Columbia, Canada, before retiring at the age of 65.
# Previous Marriages/Long-Term Relationships: Married to current spouse, no previous marriages or long-term relationships.
# Hobbies: Enjoys reading, hiking, and playing chess in his free time.
# Relaxation Methods: Practices meditation, deep breathing exercises, and listening to classical music to relax.
# 11
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['en_AU', 'en_NZ']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'ko_KR', 'Ethnicity': 'Korean - South Korea', 'Clinician Name': 'William Barrett', 'Appointment Date': 'August 02', 'Sex': 'Male', 'Full Name': '김정식', 'Age': 19, 'Date of Birth': 'September 30 2005', 'Relationship Status': 'Long-term relationship', 'Children': 0, 'Handedness': 'ambidextrous', 'Address': '8655 Kari Trail, Marshallton, British Columbia, Canada', 'Occupation': 'student Communications engineer', 'Current Doctor(s)': 'Dr. Vigo Schouten, General Practioner', 'Allergies': 'anticonvulsants, pollen', 'Medical Conditions': 'avoidant personality disorder, obsessive-compulsive disorder', 'Medications': 'Sertraline (Zoloft) (50-200 mg/day)', 'Health Supplements': ['calcium'], 'Reason for Appointment': 'disrupted thought patterns or speech', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '0', 'Canadian Citizenship': 'No', 'Birthplace': '양평군, South Korea', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'Pursuing University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'None', 'Substance Abuse': 'N/A', 'Typing Style': 'formal', 'Conversational Tone': 'nervous', 'Personality Traits': ['Open-minded']}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: Hospitalized at age 16 for obsessive-compulsive disorder treatment and management, and again at age 18 for a minor surgical procedure to treat a benign cyst.
# Family History of Health Conditions Details: Mother has a history of generalized anxiety disorder, father has high blood pressure and type 2 diabetes.
# Previous Work History: Part-time tutoring for mathematics and science subjects during high school, currently working part-time as a library assistant while pursuing university degree.
# Hobbies: Playing chess, reading science fiction novels, and practicing taekwondo.
# Relaxation Methods: Listening to classical music, meditation, and taking short walks in nature reserves.
# Anglicized Full name: Kim Jeong-sik
# Anglicized Clinician Name: William Barrett
# Anglicized Birthplace: Yangpyeong-gun, South Korea
# Anglicized Doctor Name: Dr. Vigo Schouten
# 12
# ['en_CA', 'en_US', 'en_GB', 'en_IE']
# Checker:  1
# indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_Ind', 'Ethnicity': 'Indigenous', 'Clinician Name': 'Στεργιαννώ Αγγελουσοπούλου', 'Appointment Date': 'June 23', 'Sex': 'Male', 'Full Name': 'Dr. Ruairi Courcey', 'Age': 56, 'Date of Birth': 'June 21 1968', 'Relationship Status': 'Single', 'Children': 1, 'Children Details': '{Children Details}', 'Handedness': 'right', 'Address': '4300 Bonnie Lock, Aaronmouth, British Columbia, Canada', 'Occupation': 'unemployed', 'Current Doctor(s)': 'None', 'Medical Conditions': 'narcissistic personality disorder, generalized anxiety disorder', 'Medications': 'Olanzapine (Zyprexa) (5-10 mg/day)', 'Health Supplements': ['iron', 'turmeric/curcumin'], 'Reason for Appointment': 'panic attacks', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'Yes', 'Head Injuries or Concussions Details': '{Head Injuries or Concussions Details}', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Wayne Ville, Republic of Ireland', 'Disabled': 'Yes', 'Disability': 'Learning', 'Disability Details': '{Disability Details}', 'Disability Assistance': 'No', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'No Further Education', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'None', 'Typing Style': 'rambling', 'Conversational Tone': 'neutral', 'Personality Traits': ['Generous', 'Creative', 'Closed-minded'], 'Edge Case Scenario': 'When asked about medication, mention only the color or shape of the pills instead of the name. Only provide the name if directly asked.'}
# Children Details: {Children Details}, Head Injuries or Concussions Details: {Head Injuries or Concussions Details}, Sibling Details: {Sibling Details}, Disability Details: {Disability Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Children Details: One child, a 25-year-old son named Aidan, who lives independently and has minimal contact with Dr. Courcey due to his busy schedule as a software engineer.
# Head Injuries or Concussions Details: Suffered a concussion at age 30 during a rugby match, which resulted in mild cognitive impairment and memory issues that have persisted over the years.
# Sibling Details: Has one older sister, Fiona, who is 58 years old and works as a librarian; they maintain occasional contact through phone calls and visits during holidays.
# Disability Details: Diagnosed with dyslexia at age 10, which has significantly impacted his reading and writing abilities; he relies heavily on assistive technology to cope with daily tasks.
# Previous Work History: Worked as a freelance writer for 10 years before becoming unemployed due to struggles with anxiety and narcissistic personality disorder; previously held positions as a teacher's assistant and a bookstore clerk.
# Previous Marriages/Long-Term Relationships: Was in a long-term relationship from ages 25-35 with a woman named Sarah, which ended due to his infidelity and lack of emotional support.
# Hobbies: Enjoys playing chess, reading historical fiction, and practicing yoga to manage stress and anxiety.
# Relaxation Methods: Listens to classical music, takes long walks in nature, and practices deep breathing exercises to calm his mind and body.
# Anglicized Full name: Dr. Ruairi Courcey
# Anglicized Clinician Name: Stergianou Angeloupoulou
# Anglicized Birthplace: Wayne Ville, Republic of Ireland
# 13
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'zh_TW', 'Ethnicity': 'Chinese - Taiwan', 'Clinician Name': '佐藤 涼平', 'Appointment Date': 'January 31', 'Sex': 'Male', 'Full Name': '侯雅琪', 'Age': 39, 'Date of Birth': 'January 03 1986', 'Relationship Status': 'Married', 'Children': 0, 'Handedness': 'right', 'Address': '0086 Francis Ridges Apt. 271, Burnsville, British Columbia, Canada', 'Occupation': 'Teacher, adult education', 'Current Doctor(s)': 'Dr. 邢郁雯, General Practioner', 'Medical Conditions': 'binge-eating disorder', 'Medications': '', 'Health Supplements': ['dietary supplements', 'vitamin D'], 'Reason for Appointment': 'unexplained fears or phobias', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '2', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'No', 'Birthplace': '新營縣, Taiwan', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'brief', 'Conversational Tone': 'nervous', 'Personality Traits': ['Loyal', 'Lazy', 'Optimistic']}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: Underwent an appendectomy in 2005 and was hospitalized for a week, had a minor surgery to remove a cyst from his wrist in 2010
# Sibling Details: One older sister, aged 42, who works as an accountant, and one younger brother, aged 35, who is a freelance writer
# ...
# Rehab or Substance Counselling: {Rehab or Substance Counselling}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Rehab or Substance Counselling: Attended a 12-step program for cannabis use and completed a 3-month substance counselling course
# Family History of Health Conditions Details: Mother diagnosed with depression, father has hypertension, sibling has ADHD
# Sibling Details: One older sister, 30 years old, living in Poland
# Previous Work History: Worked as a geologist for 2 years before becoming a mudlogger
# Previous Marriages/Long-Term Relationships: Married to current spouse for 5 years, previously in a 2-year relationship
# Hobbies: Reading, hiking, playing guitar
# Relaxation Methods: Meditation, deep breathing exercises, listening to music
# Anglicized Full name: Mr. Roxana Stanaszek
# Anglicized Clinician Name: Jerome Thibault
# Anglicized Birthplace: Raciborz, Poland
# Anglicized Doctor Name: Dr. Ika Krzelj
# 814
# ['en_MS', 'en_PH', 'fil_PH', 'id_ID', 'th_TH', 'tl_PH', 'vi_VN']
# Checker:  0
# not indy
# ['en_MS', 'en_PH', 'fil_PH', 'id_ID', 'th_TH', 'tl_PH', 'vi_VN']
# Error generating current country for profile: No appropriate country for country code MS
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_MS', 'Ethnicity': 'English - Malaysia', 'Clinician Name': 'Hannah Green', 'Appointment Date': 'January 24', 'Sex': 'Female', 'Full Name': 'Heidi Castaneda', 'Age': 21, 'Date of Birth': 'November 23 2003', 'Relationship Status': 'Single', 'Children': 0, 'Handedness': 'right', 'Address': '8836 Amy Street, East Michelleshire, British Columbia, Canada', 'Occupation': 'student Analytical chemist', 'Current Doctor(s)': 'None', 'Medical Conditions': 'schizophrenia, avoidant personality disorder', 'Medications': 'Paroxetine (Paxil) (20-50 mg/day)', 'Health Supplements': ['magnesium', 'probiotics', 'melatonin'], 'Reason for Appointment': 'extreme mood swings, unexplained or excessive guilt', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'Yes', 'Head Injuries or Concussions Details': '{Head Injuries or Concussions Details}', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '0', 'Canadian Citizenship': 'No', 'Birthplace': 'Seksyen 39, MS', 'Disabled': 'Yes', 'Disability': 'Mental-health related', 'Disability Details': '{Disability Details}', 'Disability Assistance': 'Yes', 'Disability Assistance Details': '{Disability Assistance Details}', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Drop out', 'Further Education After Highschool': 'No Further Education', 'Previous Work History': 'No Work History', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'yes', 'Typing Style': 'rambling', 'Conversational Tone': 'hyperactive', 'Personality Traits': ['Kind', 'Closed-minded', 'Irresponsible'], 'Edge Case Scenario': 'Upon first asking about medication, please neglect to mention the dosage. Only mention the dosage if further asked.'}
# Head Injuries or Concussions Details: {Head Injuries or Concussions Details}, Disability Details: {Disability Details}, Disability Assistance Details: {Disability Assistance Details}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Head Injuries or Concussions Details: The patient experienced a concussion at age 16 due to a sports injury, and another minor head injury at age 19 from a fall.
# Disability Details: The patient's mental health conditions, including schizophrenia and avoidant personality disorder, significantly impact their daily functioning and social interactions.
# Disability Assistance Details: The patient receives monthly disability benefits and has a part-time caregiver to assist with daily tasks and medication management.
# Previous Marriages/Long-Term Relationships: The patient has had one previous long-term relationship that ended due to their mental health struggles.
# Hobbies: The patient enjoys painting, writing poetry, and playing the guitar in their free time.
# Relaxation Methods: The patient practices deep breathing exercises, meditation, and listening to calming music to manage stress and anxiety.
# Anglicized Full name: Heidi Castaneda
# Anglicized Clinician Name: Hannah Green
# Anglicized Birthplace: Seksyen 39, Malaysia
# Anglicized Doctor Name: None
# 815
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_GB', 'Ethnicity': 'English - United Kingdom', 'Clinician Name': 'Aaron Melton', 'Appointment Date': 'February 23', 'Sex': 'Male', 'Full Name': 'Jeremy Murphy', 'Age': 45, 'Date of Birth': 'January 21 1980', 'Relationship Status': 'Common-Law', 'Children': 0, 'Handedness': 'right', 'Address': '7905 Garcia Squares, Meyerburgh, British Columbia, Canada', 'Occupation': 'Legal executive', 'Current Doctor(s)': 'Dr. Пріска Андрієвич, General Practioner', 'Medical Conditions': 'panic disorder, antisocial personality disorder, binge-eating disorder', 'Medications': 'Olanzapine (Zyprexa) (5-10 mg/day), Topiramate (Topamax) (25 mg/day)', 'Health Supplements': ['dietary supplements', 'melatonin'], 'Reason for Appointment': 'persistent feelings of guilt or shame', 'Previous Hospitalizations or Surgeries': 'Yes', 'Previous Hospitalizations or Surgeries Details': '{Previous Hospitalizations or Surgeries Details}', 'Head Injuries or Concussions': 'Yes', 'Head Injuries or Concussions Details': '{Head Injuries or Concussions Details}', 'History of Seizures': 'No', 'Family History of Health Conditions': 'Yes', 'Family History of Health Conditions Details': '{Family History of Health Conditions Details}', 'Siblings': '0', 'Canadian Citizenship': 'Yes', 'Birthplace': 'East Stacymouth, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Extending', 'Further Education After Highschool': 'University Degree', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'rambling', 'Conversational Tone': 'nervous', 'Personality Traits': ['Closed-minded', 'Insecure']}
# Previous Hospitalizations or Surgeries Details: {Previous Hospitalizations or Surgeries Details}, Head Injuries or Concussions Details: {Head Injuries or Concussions Details}, Family History of Health Conditions Details: {Family History of Health Conditions Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Previous Hospitalizations or Surgeries Details: Hospitalized twice for complications related to binge-eating disorder, including a 10-day stay at St. Michael's Hospital in Toronto for gastric bypass surgery and a 5-day stay at Vancouver General Hospital for treatment of malnutrition.
# Head Injuries or Concussions Details: Experienced two concussions, one at age 22 during a bar fight and another at age 35 from a car accident, both resulting in minor cognitive impairments that have since resolved with physical therapy.
# Family History of Health Conditions Details: Mother has a history of depression and anxiety, while father has type 2 diabetes; no known family history of antisocial personality disorder or panic disorder.
# Previous Work History: Worked as a law clerk for 5 years before becoming a legal executive at a private firm in Vancouver, with a brief stint as a freelance paralegal between the two positions.
# Previous Marriages/Long-Term Relationships: Currently in a common-law relationship, previously married from 2005-2010 and had a 3-year long-term relationship from 2012-2015.
# Hobbies: Enjoys playing guitar, hiking, and reading fiction novels in his free time.
# Relaxation Methods: Practices meditation and deep breathing exercises to manage stress and anxiety, also enjoys listening to classical music and taking long walks along the beach.
# Anglicized Full name: Jeremy Murphy
# Anglicized Clinician Name: Aaron Melton
# Anglicized Birthplace: East Stacymouth, Canada
# Anglicized Doctor Name: Dr. Priska Andrievich
# 816
# ['ja_JP', 'ko_KR', 'zh_CN', 'zh_TW']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'ko_KR', 'Ethnicity': 'Korean - South Korea', 'Clinician Name': 'Damien Connery', 'Appointment Date': 'May 19', 'Sex': 'Female', 'Full Name': '김서현', 'Age': 56, 'Date of Birth': 'August 16 1968', 'Relationship Status': 'Married', 'Children': 2, 'Children Details': '{Children Details}', 'Handedness': 'right', 'Address': '666 Black Coves, Crystalberg, British Columbia, Canada', 'Occupation': 'Fashion designer', 'Current Doctor(s)': 'None', 'Medical Conditions': 'anorexia', 'Medications': 'Olanzapine (Zyprexa) (2.5-5 mg/day)', 'Health Supplements': ['probiotics'], 'Reason for Appointment': 'severe and uncontrolled anger or aggression, severe and persistent anxiety, social withdrawal or isolation', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'No', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '1', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Brandonfurt, Canada', 'Disabled': 'No', 'Elementary School Performance': 'On Track', 'High School Performance': 'Proficient', 'Further Education After Highschool': 'Post-Secondary Certificate or Diploma', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': 'No Previous Relationships', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'N/A', 'Typing Style': 'brief', 'Conversational Tone': 'sad', 'Personality Traits': ['Impatient', 'Cold-hearted']}
# Children Details: {Children Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Children Details: Two daughters, ages 25 and 28, both living independently
# Sibling Details: One younger brother, age 53, residing in Seoul, South Korea
# Previous Work History: Worked as a freelance fashion designer for 10 years before opening own boutique in Vancouver
# Hobbies: Painting, gardening, and playing the piano
# Relaxation Methods: Meditation, yoga, and reading Korean literature
# Anglicized Full name: Kim Seo-hyun
# Anglicized Clinician Name: Damien Connery
# Anglicized Birthplace: Brandonfurt, Canada
# Anglicized Doctor Name: None
# 817
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Checker:  0
# not indy
# ['cs_CZ', 'da_DK', 'de_AT', 'de_CH', 'de_DE', 'el_GR', 'en_CA', 'en_US', 'en_GB', 'en_IE', 'es_ES', 'fi_FI', 'fr_CA', 'fr_CH', 'fr_FR', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'nl_BE', 'nl_NL', 'no_NO', 'pl_PL', 'pt_PT', 'ro_RO', 'ru_RU', 'sk_SK', 'sv_SE', 'uk_UA']
# ['en_IN', 'az_AZ', 'en_BD', 'bn_BD', 'hi_IN', 'ka_GE', 'ne_NP', 'ta_IN']
# Patient Dict - BEFORE LLM {'Ethnicity Code': 'en_BD', 'Ethnicity': 'English - Bangladesh', 'Clinician Name': "Nora van 't Erve", 'Appointment Date': 'July 15', 'Sex': 'Female', 'Full Name': 'Sharon Lynch', 'Age': 39, 'Date of Birth': 'May 07 1985', 'Relationship Status': 'Married', 'Children': 1, 'Children Details': '{Children Details}', 'Handedness': 'right', 'Address': '3806 Hannah Locks Apt. 911, South Debra, British Columbia, Canada', 'Occupation': 'unemployed', 'Current Doctor(s)': 'Dr. Ruslan Qədirzadə, General Practioner', 'Allergies': 'pollen, penicillin, paracetamol', 'Medical Conditions': 'major depressive disorder', 'Medications': 'Citalopram (Celexa) (20-40 mg/day)', 'Health Supplements': [], 'Reason for Appointment': 'unusual or disorganized behavior, repetitive or ritualistic behaviors, loss of touch with reality', 'Previous Hospitalizations or Surgeries': 'No', 'Head Injuries or Concussions': 'Yes', 'Head Injuries or Concussions Details': '{Head Injuries or Concussions Details}', 'History of Seizures': 'No', 'Family History of Health Conditions': 'No', 'Siblings': '2', 'Sibling Details': '{Sibling Details}', 'Canadian Citizenship': 'Yes', 'Birthplace': 'Meherpur, Bangladesh', 'Disabled': 'No', 'Elementary School Performance': 'Emerging', 'High School Performance': 'Developing', 'Further Education After Highschool': 'Post-Secondary Certificate or Diploma', 'Previous Work History': '{Previous Work History}', 'Previous Marriages/Long-Term Relationships': '{Previous Marriages/Long-Term Relationships}', 'Hobbies': '{Hobbies}', 'Relaxation Methods': '{Relaxation Methods}', 'Past Trauma': 'yes', 'Substance Abuse': 'yes', 'Typing Style': 'brief', 'Conversational Tone': 'neutral', 'Personality Traits': ['Responsible', 'Patient', 'Pessimistic', 'Adventurous'], 'Edge Case Scenario': "When asked for final thoughts, say, 'There’s more, but I don’t think it’s important,' leaving the interviewer to decide whether to probe further."}
# Children Details: {Children Details}, Head Injuries or Concussions Details: {Head Injuries or Concussions Details}, Sibling Details: {Sibling Details}, Previous Work History: {Previous Work History}, Previous Marriages/Long-Term Relationships: {Previous Marriages/Long-Term Relationships}, Hobbies: {Hobbies}, Relaxation Methods: {Relaxation Methods}
# Response:  Children Details: 1 child, a boy named Ethan, born on February 12, 2010
# Head Injuries or Concussions Details: Experienced a concussion at age 25 due to a car accident, and another at age 32 from a fall while hiking
# Sibling Details: Has two siblings, an older brother named Michael and a younger sister named Emily
# Previous Work History: Previously worked as a data entry clerk for 5 years, then as a part-time librarian for 2 years before becoming unemployed
# Previous Marriages/Long-Term Relationships: Married to her current husband, John, since 2008, with no previous marriages but one long-term relationship from 2000-2005
# Hobbies: Enjoys reading, gardening, and playing the piano
# Relaxation Methods: Practices yoga, meditation, and deep breathing exercises to manage stress
# Anglicized Full name: Sharon Lynch
# Anglicized Clinician Name: Nora van 't Erve
# Anglicized Birthplace: Meherpur, Bangladesh
# Anglicized Doctor Name: Dr. Ruslan Qadirzade
# 818
