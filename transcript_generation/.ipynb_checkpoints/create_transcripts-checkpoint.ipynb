# %% [markdown]
# Before running this code block, you will need to create a ".env" file in the main directory. In the ".env" file, you need to add this line: `OPENAI_API_KEY = <OpenAI API Key>`. Replace `<OpenAI API Key>` with your API key from the OpenAI website. It is important to keep your API Keys private.

# %%
import os, sys
from pathlib import Path
from datetime import datetime
import csv
import pandas as pd
import random

print(Path.cwd())

# from double_model import double_model_llama
from double_model import double_model_chunking_v2
# from single_model import single_model_llama
# Out:
# C:\Users\aleynaw\Desktop\transcript_generation-main\transcript_generation

# %%
### read the patients csv
patients_path = Path("../patient_creation/llm_patients.csv")
patients_df = pd.read_csv(patients_path,delimiter="|")

# print(patients_df)
# print("number of patients:", len(patients_df))

# %%
folder_name = "llama3.1"
Path.mkdir(Path(Path.cwd(), "transcripts", folder_name), exist_ok=True)

# %%
#ssh ninc-user@10.20.242.33 -L 11435:localhost:11434

# %%
random.seed()
### pass in a patient to create an interview
for i, patient in patients_df.iterrows():
    output_id = datetime.now().strftime("%Y%m%d-%H%M%S")
    patient_dict = patient.dropna().to_dict()
    # print(patient_dict.keys())
    print(i, patient_dict["Full Name"])
    double_model_chunking_v2.interview_gen(patient=patient_dict, output_id=output_id, out_dir=f"./transcripts/{folder_name}/DM")
    # double_model.interview_gen(patient=patient_dict, output_id=output_id,out_dir=f"./transcripts/{folder_name}/DM")
    # single_model.interview_gen(patient=patient_dict, output_id=output_id, out_dir=f"./transcripts/{folder_name}/SM")

    #### use the code below instead if you want to generate a transcript for a certain patient
    
    # if i == 0:
    #     output_id = datetime.now().strftime("%Y%m%d-%H%M%S")
    #     patient_dict = patient.dropna().to_dict()
    #     print(i, patient_dict["Full Name"])
    #     # double_model.interview_gen(patient=patient_dict, output_id=output_id,out_dir=f"./transcripts/{folder_name}/DM")
    #     # double_model_llama.interview_gen(patient=patient_dict, output_id=output_id, out_dir=f"./transcripts/{folder_name}/DM") 
    #     double_model_chunking_v2.interview_gen(patient=patient_dict, output_id=output_id, out_dir=f"./transcripts/{folder_name}/DM")
# Out:
# 0 Clarisa Mora Reig
# ['## General Information ## # Personal Information\n- full name', '- preferred name', '- date of birth', '- sex', '- handedness: left, right, both']
# ['## General Information ## # Residence and Marital Status\n- current city/town of residence', '- single, in a relationship, married, common law?', '- any children or dependents?', '+ if yes, names and ages?']
# ['## General Information ## # Employment and Financial Status\n- currently working?', '+ if yes, name of company? years working?', '- disability assistance status', '+ if yes, what type and when?']
# ['## Medical History ## # Medical Care Information\n- current doctors?', '- allergies', '- current medications and dosage?', '- health supplements', '- frequency of nicotine, marijuana, alcohol use?']
# ['## Medical History ## # General Health\n- health conditions/diagnoses and details such as when you were diagnosed?', '- previous hospitalizations, surgeries']
# ['## Medical History ## # Neurological and Mental Health\n- history of head injuries/concussions', '+ if yes, when and how?', '- history of seizures', '+ if yes, when it started?', '- history of rehab or substance counselling', '+ if yes, where? when?']
# ['## Family History ## # Professional Care\n- other medical professionals seen', '+ if yes, who/when/why?']
# ['## Family History ## # Mental and Neurological Health\n- history of psychiatric conditions in other family members', '+ if yes, who? did they receive treatment or hospital care?', '- family history of neurological or genetic conditions', '+ if yes, who? did they receive treatment or hospital care?']
# ['## Personal History ## # Siblings\n- siblings', "+ if yes, ask for each sibling's basic info such as name, age, where they live, occupation"]
# ['## Personal History ## # Early Life and Citizenship\n- where were you born?', '+ if outside canada, year of arrival?', '- are you a canadian citizen?', '- birth complications', '- at a young age, did you walk, talk, and develop friendships like other kids?']
# ['## Personal History ## # Education\n- difficulties in elementary school', '- average mark and favorite topic/class in high school', '- further education after high school', '+ if yes, where and what type of studies?']
# ['## Personal History ## # Employment and Relationships\n- previous work history', '+ if yes, companies and years of work?', '- any previous marriages/long term relationships']
# ['## Other Questions ## # Hobbies and Lifestyle\n- hobbies', '- what do you do to relax on a stressful day?']
# ['## END OF INTERVIEW ## # Final Thoughts\n- anything the doctor needs to know']
# if turns ==  5  +  0
# Patient extracted response:  I'm willing to share some background information, but I'd appreciate it if we could keep the conversation focused and relevant to my appointment with Dr. Quinn. I want to make sure I'm prepared for our meeting.
# Assistant extracted response:  Thank you for being willing to share some background information. To start, could you please tell me your full name?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
#
# Turn count: 1
# if turns ==  5  +  0
# Patient extracted response:  "My full name is Clarisa Mora Reig."
# Assistant extracted response:  Thank you for sharing that with me. Could you please tell me your preferred name, or how you would like to be addressed?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
#
# Turn count: 2
# if turns ==  5  +  0
# Patient extracted response:  "You can call me Clarisa. That's what most people close to me use."
# Assistant extracted response:  Thank you for letting me know, Clarisa. Now, could you please tell me your date of birth?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
#
# Turn count: 3
# if turns ==  5  +  0
# Patient extracted response:  "November 29, 1960."
# Assistant extracted response:  Thank you for sharing that with me. Could you please tell me your sex?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
#
# Turn count: 4
# if turns ==  5  +  0
# Patient extracted response:  I am female.
# Assistant extracted response:  Thank you for letting me know, Clarisa. Now, I'd like to ask about your handedness. Are you left-handed, right-handed, or do you use both hands equally?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
#
# Turn count: 5
# if turns ==  5  +  0
# Updating assistant prompt...
# Patient extracted response:  "I'm right-handed."
# Assistant extracted response:  Thank you for letting me know, Clarisa. I'd like to move on to discuss your residence and marital status. Could you please tell me what city or town you currently reside in?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
#
# Turn count: 6
# if turns ==  3  +  5
# Patient extracted response:  I currently live in Rodriguezville.
# Assistant extracted response:  Thank you for letting me know, Clarisa. That's helpful information. Now, regarding your marital status, are you single, in a relationship, married, or common law?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
#
# Turn count: 7
# if turns ==  3  +  5
# Patient extracted response:  "I'm currently in a long-term relationship."
# Assistant extracted response:  Thank you for sharing that with me, Clarisa. Now, I'd like to ask if you have any children or dependents?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
#
# Turn count: 8
# if turns ==  3  +  5
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': 'Good day, I am Dr. Antonio Quinnâ€™s Interview Assistant and I was asked to connect with you before your appointment on October 12 at the medical clinic. My goal is to gather some background information for the doctor.\nI am an AI Assistant and in compliance with confidentiality regulations (BC Protection of Privacy), the data transmission for this interview and analysis is located in Canada, and all information I gather will be stored privately and only available for Dr. Antonio Quinn to review. Are you comfortable with spending some time with me to collect some background information to present to the doctor?'}, {'role': 'user', 'content': "I'm willing to share some background information, but I'd appreciate it if we could keep the conversation focused and relevant to my appointment with Dr. Quinn. I want to make sure I'm prepared for our meeting."}, {'role': 'assistant', 'content': 'Thank you for being willing to share some background information. To start, could you please tell me your full name?'}, {'role': 'user', 'content': '"My full name is Clarisa Mora Reig."'}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Could you please tell me your preferred name, or how you would like to be addressed?'}, {'role': 'user', 'content': '"You can call me Clarisa. That\'s what most people close to me use."'}, {'role': 'assistant', 'content': 'Thank you for letting me know, Clarisa. Now, could you please tell me your date of birth?'}, {'role': 'user', 'content': '"November 29, 1960."'}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Could you please tell me your sex?'}, {'role': 'user', 'content': 'I am female.'}, {'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. Now, I'd like to ask about your handedness. Are you left-handed, right-handed, or do you use both hands equally?"}, {'role': 'user', 'content': '"I\'m right-handed."'}, {'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. I'd like to move on to discuss your residence and marital status. Could you please tell me what city or town you currently reside in?"}, {'role': 'user', 'content': 'I currently live in Rodriguezville.'}, {'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. That's helpful information. Now, regarding your marital status, are you single, in a relationship, married, or common law?"}, {'role': 'user', 'content': '"I\'m currently in a long-term relationship."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me, Clarisa. Now, I'd like to ask if you have any children or dependents?"}]
# Message_list length:  16
# Message_list length:  15
# Message_list length:  14
# Message_list length:  13
# Message_list length:  12
# Message_list length:  11
# Message_list length:  10
# Message_list length:  9
# Message_list length:  8
# Message_list length:  7
# Updating assistant prompt...
# Patient extracted response:  No, I don't have any children.
# Assistant extracted response:  Thank you for letting me know that. Now, I'd like to move on to discuss your employment and financial status. Are you currently working?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
#
# Turn count: 9
# if turns ==  2  +  8
# Patient extracted response:  No, I am not currently working.
# Assistant extracted response:  Thank you for letting me know that. Now, I'd like to ask if you currently receive any disability assistance?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
#
# Turn count: 10
# if turns ==  2  +  8
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. Now, I'd like to ask about your handedness. Are you left-handed, right-handed, or do you use both hands equally?"}, {'role': 'user', 'content': '"I\'m right-handed."'}, {'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. I'd like to move on to discuss your residence and marital status. Could you please tell me what city or town you currently reside in?"}, {'role': 'user', 'content': 'I currently live in Rodriguezville.'}, {'role': 'assistant', 'content': "Thank you for letting me know, Clarisa. That's helpful information. Now, regarding your marital status, are you single, in a relationship, married, or common law?"}, {'role': 'user', 'content': '"I\'m currently in a long-term relationship."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me, Clarisa. Now, I'd like to ask if you have any children or dependents?"}, {'role': 'user', 'content': "No, I don't have any children."}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to move on to discuss your employment and financial status. Are you currently working?"}, {'role': 'user', 'content': 'No, I am not currently working.'}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to ask if you currently receive any disability assistance?"}]
# Message_list length:  10
# Message_list length:  9
# Message_list length:  8
# Message_list length:  7
# Message_list length:  6
# Message_list length:  5
# Updating assistant prompt...
# Patient extracted response:  No, I don't receive any disability assistance.
# Assistant extracted response:  Thank you for letting me know that. Now, I'd like to move on to discuss your medical history. Could you please tell me about any current doctors you are seeing?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
#
# Turn count: 11
# if turns ==  5  +  10
# Patient extracted response:  "I currently see two doctors, Dr. Rachel Kim and Dr. Eric Taylor."
# Assistant extracted response:  Thank you for sharing that with me. You mentioned Dr. Rachel Kim and Dr. Eric Taylor as your current doctors. Do either of them specialize in treating anxiety or mental health issues, or is there another specialist you see for those concerns?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
#
# Turn count: 12
# if turns ==  5  +  10
# Patient extracted response:  "Yes, Dr. Eric Taylor is my psychiatrist, so he specializes in treating mental health issues, including anxiety concerns."
# Assistant extracted response:  Thank you for sharing that with me. Now, I'd like to ask if you have any known allergies?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
#
# Turn count: 13
# if turns ==  5  +  10
# Patient extracted response:  Yes, I have allergies to acetaminophen, latex, and pet dander.
# Assistant extracted response:  Thank you for sharing that with me. Now, I'd like to ask about your current medications and dosage. Are you taking any prescription or over-the-counter medications at this time?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
#
# Turn count: 14
# if turns ==  5  +  10
# Patient extracted response:  I'm taking Paxil.
# Assistant extracted response:  Thank you for sharing that with me. Could you please tell me more about your Paxil prescription, such as the dosage and how often you take it?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
#
# Turn count: 15
# if turns ==  5  +  10
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': "Thank you for sharing that with me, Clarisa. Now, I'd like to ask if you have any children or dependents?"}, {'role': 'user', 'content': "No, I don't have any children."}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to move on to discuss your employment and financial status. Are you currently working?"}, {'role': 'user', 'content': 'No, I am not currently working.'}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to ask if you currently receive any disability assistance?"}, {'role': 'user', 'content': "No, I don't receive any disability assistance."}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to move on to discuss your medical history. Could you please tell me about any current doctors you are seeing?"}, {'role': 'user', 'content': '"I currently see two doctors, Dr. Rachel Kim and Dr. Eric Taylor."'}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. You mentioned Dr. Rachel Kim and Dr. Eric Taylor as your current doctors. Do either of them specialize in treating anxiety or mental health issues, or is there another specialist you see for those concerns?'}, {'role': 'user', 'content': '"Yes, Dr. Eric Taylor is my psychiatrist, so he specializes in treating mental health issues, including anxiety concerns."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me. Now, I'd like to ask if you have any known allergies?"}, {'role': 'user', 'content': 'Yes, I have allergies to acetaminophen, latex, and pet dander.'}, {'role': 'assistant', 'content': "Thank you for sharing that with me. Now, I'd like to ask about your current medications and dosage. Are you taking any prescription or over-the-counter medications at this time?"}, {'role': 'user', 'content': "I'm taking Paxil."}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Could you please tell me more about your Paxil prescription, such as the dosage and how often you take it?'}]
# Message_list length:  14
# Message_list length:  13
# Message_list length:  12
# Message_list length:  11
# Updating assistant prompt...
# Patient extracted response:  The dosage of my Paxil prescription is 20-50 mg per day.
# Assistant extracted response:  Thank you for sharing that. Could you please specify how often you take Paxil, such as once daily or as needed?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
#
# Turn count: 16
# if turns ==  2  +  15
# Patient extracted response:  I take it once daily, I think. It's been part of my routine for as long as I can remember.
# Assistant extracted response:  Thank you for sharing that with me. Just to clarify, do you mean that you take Paxil every day without fail, or is there some variation in your routine?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
#
# Turn count: 17
# if turns ==  2  +  15
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to ask if you currently receive any disability assistance?"}, {'role': 'user', 'content': "No, I don't receive any disability assistance."}, {'role': 'assistant', 'content': "Thank you for letting me know that. Now, I'd like to move on to discuss your medical history. Could you please tell me about any current doctors you are seeing?"}, {'role': 'user', 'content': '"I currently see two doctors, Dr. Rachel Kim and Dr. Eric Taylor."'}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. You mentioned Dr. Rachel Kim and Dr. Eric Taylor as your current doctors. Do either of them specialize in treating anxiety or mental health issues, or is there another specialist you see for those concerns?'}, {'role': 'user', 'content': '"Yes, Dr. Eric Taylor is my psychiatrist, so he specializes in treating mental health issues, including anxiety concerns."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me. Now, I'd like to ask if you have any known allergies?"}, {'role': 'user', 'content': 'Yes, I have allergies to acetaminophen, latex, and pet dander.'}, {'role': 'assistant', 'content': "Thank you for sharing that with me. Now, I'd like to ask about your current medications and dosage. Are you taking any prescription or over-the-counter medications at this time?"}, {'role': 'user', 'content': "I'm taking Paxil."}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Could you please tell me more about your Paxil prescription, such as the dosage and how often you take it?'}, {'role': 'user', 'content': 'The dosage of my Paxil prescription is 20-50 mg per day.'}, {'role': 'assistant', 'content': 'Thank you for sharing that. Could you please specify how often you take Paxil, such as once daily or as needed?'}, {'role': 'user', 'content': "I take it once daily, I think. It's been part of my routine for as long as I can remember."}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Just to clarify, do you mean that you take Paxil every day without fail, or is there some variation in your routine?'}]
# Message_list length:  14
# Message_list length:  13
# Message_list length:  12
# Message_list length:  11
# Message_list length:  10
# Message_list length:  9
# Message_list length:  8
# Message_list length:  7
# Message_list length:  6
# Message_list length:  5
# Updating assistant prompt...
# Patient extracted response:  Honestly, I try to take it every day without fail, but like anyone, I'm sure there have been instances where I've missed a dose or two over the years. Generally, though, taking Paxil once daily is part of my consistent morning routine.
# Assistant extracted response:  Thank you for sharing that with me; it's helpful to understand your routine. Moving on, could you tell me a bit about any health supplements you're currently taking?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
#
# Turn count: 18
# if turns ==  3  +  17
# Patient extracted response:  I'm not taking any health supplements.
# Assistant extracted response:  Thank you for letting me know. Now, could you tell me about your frequency of using nicotine, marijuana, or alcohol?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
#
# Turn count: 19
# if turns ==  3  +  17
# Patient extracted response:  "It's hard for me to talk about this, but... I have used substances in the past. I'd rather not go into details, but I want to acknowledge it. As for current use, I don't think I can provide a specific frequency."
# Assistant extracted response:  Thank you for sharing that with me; it helps to understand your situation. Moving on, could you tell me about any health conditions or diagnoses you've received? For example, have you ever been diagnosed with diabetes or high blood pressure?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
#
# Turn count: 20
# if turns ==  3  +  17
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': 'Thank you for sharing that with me. Could you please tell me more about your Paxil prescription, such as the dosage and how often you take it?'}, {'role': 'user', 'content': 'The dosage of my Paxil prescription is 20-50 mg per day.'}, {'role': 'assistant', 'content': 'Thank you for sharing that. Could you please specify how often you take Paxil, such as once daily or as needed?'}, {'role': 'user', 'content': "I take it once daily, I think. It's been part of my routine for as long as I can remember."}, {'role': 'assistant', 'content': 'Thank you for sharing that with me. Just to clarify, do you mean that you take Paxil every day without fail, or is there some variation in your routine?'}, {'role': 'user', 'content': "Honestly, I try to take it every day without fail, but like anyone, I'm sure there have been instances where I've missed a dose or two over the years. Generally, though, taking Paxil once daily is part of my consistent morning routine."}, {'role': 'assistant', 'content': "Thank you for sharing that with me; it's helpful to understand your routine. Moving on, could you tell me a bit about any health supplements you're currently taking?"}, {'role': 'user', 'content': "I'm not taking any health supplements."}, {'role': 'assistant', 'content': 'Thank you for letting me know. Now, could you tell me about your frequency of using nicotine, marijuana, or alcohol?'}, {'role': 'user', 'content': '"It\'s hard for me to talk about this, but... I have used substances in the past. I\'d rather not go into details, but I want to acknowledge it. As for current use, I don\'t think I can provide a specific frequency."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me; it helps to understand your situation. Moving on, could you tell me about any health conditions or diagnoses you've received? For example, have you ever been diagnosed with diabetes or high blood pressure?"}]
# Message_list length:  10
# Message_list length:  9
# Message_list length:  8
# Message_list length:  7
# Updating assistant prompt...
# Patient extracted response:  "I have been diagnosed with avoidant personality disorder, and I've also experienced some significant medical events in the past, including a severe depressive episode that required hospitalization. Additionally, there's a history of mental health conditions in my family. I want to note that these experiences have had a significant impact on my life, but I'm working to manage them with treatment and support."
# Assistant extracted response:  Thank you for sharing this information; it's helpful in understanding your situation better. If you're comfortable doing so, could you tell me more about the severe depressive episode that led to your hospitalization? Specifically, when did this occur and what treatment plan was implemented during your stay?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
#
# Turn count: 21
# if turns ==  1  +  20
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': 'Thank you for sharing that with me. Just to clarify, do you mean that you take Paxil every day without fail, or is there some variation in your routine?'}, {'role': 'user', 'content': "Honestly, I try to take it every day without fail, but like anyone, I'm sure there have been instances where I've missed a dose or two over the years. Generally, though, taking Paxil once daily is part of my consistent morning routine."}, {'role': 'assistant', 'content': "Thank you for sharing that with me; it's helpful to understand your routine. Moving on, could you tell me a bit about any health supplements you're currently taking?"}, {'role': 'user', 'content': "I'm not taking any health supplements."}, {'role': 'assistant', 'content': 'Thank you for letting me know. Now, could you tell me about your frequency of using nicotine, marijuana, or alcohol?'}, {'role': 'user', 'content': '"It\'s hard for me to talk about this, but... I have used substances in the past. I\'d rather not go into details, but I want to acknowledge it. As for current use, I don\'t think I can provide a specific frequency."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me; it helps to understand your situation. Moving on, could you tell me about any health conditions or diagnoses you've received? For example, have you ever been diagnosed with diabetes or high blood pressure?"}, {'role': 'user', 'content': '"I have been diagnosed with avoidant personality disorder, and I\'ve also experienced some significant medical events in the past, including a severe depressive episode that required hospitalization. Additionally, there\'s a history of mental health conditions in my family. I want to note that these experiences have had a significant impact on my life, but I\'m working to manage them with treatment and support."'}, {'role': 'assistant', 'content': "Thank you for sharing this information; it's helpful in understanding your situation better. If you're comfortable doing so, could you tell me more about the severe depressive episode that led to your hospitalization? Specifically, when did this occur and what treatment plan was implemented during your stay?"}]
# Message_list length:  8
# Message_list length:  7
# Message_list length:  6
# Message_list length:  5
# Message_list length:  4
# Message_list length:  3
# Updating assistant prompt...
# Patient extracted response:  "I was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode. It was a really tough time for me, and I'm still working through some of those emotions. As for treatment, I started taking Paroxetine, also known as Paxil, which has been helpful in managing my symptoms."
# Assistant extracted response:  Thank you for sharing that with me. I appreciate your openness about this difficult experience. Now, let's move on to discuss other aspects of your medical history. Have you ever experienced any head injuries or concussions?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
#
# Turn count: 22
# if turns ==  2  +  21
# Patient extracted response:  "Yes, I have experienced head injuries and concussions. I had a concussion in 1985 from a car accident, and I also had some mild head trauma in 1992 after a fall while hiking. I've been fortunate that these incidents didn't have any long-term effects on my daily life, but they were certainly scary experiences at the time."
# Assistant extracted response:  Thank you for sharing that information about your head injuries. I'd like to move on and ask if you have ever had any seizures?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
# Head injuries/concussions: Patient experienced a concussion in 1985 and mild head trauma in 1992, both with no reported long-term effects.
#
# Turn count: 23
# if turns ==  2  +  21
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# [{'role': 'assistant', 'content': "Thank you for sharing that with me; it helps to understand your situation. Moving on, could you tell me about any health conditions or diagnoses you've received? For example, have you ever been diagnosed with diabetes or high blood pressure?"}, {'role': 'user', 'content': '"I have been diagnosed with avoidant personality disorder, and I\'ve also experienced some significant medical events in the past, including a severe depressive episode that required hospitalization. Additionally, there\'s a history of mental health conditions in my family. I want to note that these experiences have had a significant impact on my life, but I\'m working to manage them with treatment and support."'}, {'role': 'assistant', 'content': "Thank you for sharing this information; it's helpful in understanding your situation better. If you're comfortable doing so, could you tell me more about the severe depressive episode that led to your hospitalization? Specifically, when did this occur and what treatment plan was implemented during your stay?"}, {'role': 'user', 'content': '"I was hospitalized at St. Michael\'s Hospital in 2010 for a severe depressive episode. It was a really tough time for me, and I\'m still working through some of those emotions. As for treatment, I started taking Paroxetine, also known as Paxil, which has been helpful in managing my symptoms."'}, {'role': 'assistant', 'content': "Thank you for sharing that with me. I appreciate your openness about this difficult experience. Now, let's move on to discuss other aspects of your medical history. Have you ever experienced any head injuries or concussions?"}, {'role': 'user', 'content': '"Yes, I have experienced head injuries and concussions. I had a concussion in 1985 from a car accident, and I also had some mild head trauma in 1992 after a fall while hiking. I\'ve been fortunate that these incidents didn\'t have any long-term effects on my daily life, but they were certainly scary experiences at the time."'}, {'role': 'assistant', 'content': "Thank you for sharing that information about your head injuries. I'd like to move on and ask if you have ever had any seizures?"}]
# Message_list length:  6
# Message_list length:  5
# Updating assistant prompt...
# Patient extracted response:  "I have had seizures in the past. It's a bit of a sensitive topic for me, but I'll try to share more if you'd like."
# Assistant extracted response:  Thank you for sharing that with me. I appreciate your willingness to discuss this sensitive topic. Could you tell me more about when your seizures started and how often they occur?
# Notes so far:  Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
# Head injuries/concussions: Patient experienced a concussion in 1985 and mild head trauma in 1992, both with no reported long-term effects.
# Seizure history: Patient has experienced seizures in the past, which is a sensitive topic for them.
#
# Turn count: 24
# if turns ==  1  +  23
#
# Dumping first questions.........................................................
# Saving and dumping previous messages..............................................
# ...
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
# Head injuries/concussions: Patient experienced a concussion in 1985 and mild head trauma in 1992, both with no reported long-term effects.
# Seizure history: Patient has experienced seizures in the past, which is a sensitive topic for them.
# Seizure information: Patient is unsure of the timing and frequency of their seizures; they find it difficult to discuss due to personal discomfort.
# Family psychiatric history: Mother with bipolar disorder; paternal grandfather with schizophrenia; maternal aunt with borderline personality disorder.
# Sibling information: One sibling, an older brother named Michael, aged 65, living in Toronto, working as an accountant.
# Birthplace: Burtonton, British Columbia, Canada; No known significant birth complications or concerns.
# Early childhood development: Patient is unsure about developmental milestones and reports difficulty with forming friendships.
# Elementary school performance: Average performance with no significant struggles or issues noted; patient mentions earlier developmental difficulties.
# High school experience: Patient did not perform well and had a difficult time, with no clear favorite subject or class.
# Further education: Patient did not pursue any education after high school due to personal challenges.
# Work history: Patient has two previous jobs - 15 years at Bell Canada (1980-1995) and 7 years at the University of British Columbia (2001-2008).
# Relationship history: Married to John Lee (divorced in 1998); in a long-term relationship with Sarah Thompson (2002-2012).
# Hobbies: Reading historical fiction, practicing yoga, and gardening.
# Stress relaxation techniques: Listening to classical music, practicing deep breathing exercises, and taking walks in nature.
# Final thoughts and concerns: Patient appreciates the conversation and feels it has been helpful; no further concerns or topics were mentioned.
# Final thoughts/concerns: Patient expressed appreciation for the conversation and found it helpful for reflection.
#
# Assistant extracted response:  Here are the edited notes:
#
# * Clarisa Mora Reig (preferred name: Clarisa)
#     - Date of birth: November 29, 1960
#     - Sex: Female
#     - Handedness: Right-handed
#     - Current residence: Rodriguezville
#     - Marital status: In a long-term relationship
#     - Children or dependents: No
#     - Employment status: Not currently employed
# * Medical information:
#     - Allergies: Acetaminophen, latex, pet dander
#     - Current medications: Paxil (20-50 mg per day) taken once daily
#     - Medication adherence: Generally takes Paxil once daily but occasionally misses doses
# * Health history:
#     - Diagnoses: Avoidant personality disorder
#     - Medical events: Hospitalized for severe depressive episode in 2010 at St. Michael's Hospital
#     - Head injuries/concussions: Concussion in 1985, mild head trauma in 1992
#     - Seizure history: Experienced seizures in the past (frequency and timing unclear)
# * Family psychiatric history:
#     - Mother with bipolar disorder
#     - Paternal grandfather with schizophrenia
#     - Maternal aunt with borderline personality disorder
#
# Thank you for your time today, Clarisa. Your input has been greatly appreciated.
#
# <STOP>
# Saving  {'role': 'assistant', 'content': 'Thank you for sharing your work history with me. Moving on, could you tell me a bit about any previous marriages or long-term relationships?'}
# Saving  {'role': 'user', 'content': '"I\'ve been married once, to John Lee, but we divorced in 1998. After that, I was in a long-term relationship with Sarah Thompson from 2002 to 2012."'}
# Saving  {'role': 'assistant', 'content': 'Thank you for sharing that with me. Moving on, could you tell me a bit about your hobbies and what you enjoy doing in your free time?'}
# Saving  {'role': 'user', 'content': '"I really enjoy reading historical fiction in my free time. It helps me escape into another world. I also practice yoga regularly, which helps me relax and calm my mind. And, I love spending time gardening - it\'s so fulfilling to see things grow."'}
# Saving  {'role': 'assistant', 'content': 'Thank you for sharing your hobbies with me. What do you usually do to relax on a stressful day?'}
# Saving  {'role': 'user', 'content': "When I'm feeling stressed, I usually listen to classical music, practice deep breathing exercises, or take a walk in nature. These activities really help calm me down and clear my mind."}
# Saving  {'role': 'assistant', 'content': "Thank you for sharing that with me. Moving on, do you have any final thoughts or concerns that you'd like to discuss before we conclude our conversation?"}
# Saving  {'role': 'user', 'content': '"I\'m not sure if there\'s anything else I\'d like to discuss, but I appreciate the opportunity to share my thoughts and feelings with you. It\'s been helpful for me to reflect on my experiences."'}
# Saving  {'role': 'assistant', 'content': 'Thank you for taking the time to speak with me today. I appreciate your honesty and openness throughout our conversation. This concludes our interview.'}
# Saving  {'role': 'user', 'content': '"I appreciate the opportunity to share my thoughts and feelings with you. It\'s been helpful for me to reflect on my experiences. I\'m feeling a bit relieved that our conversation is coming to an end, as it can be emotionally draining to discuss some of these topics. But overall, I\'m grateful for your listening ear and empathetic approach."'}
# Saving  {'role': 'assistant', 'content': '<STOP>'}
# Saving  {'role': 'assistant', 'content': "Here are the edited notes:\n\n* Clarisa Mora Reig (preferred name: Clarisa) \n    - Date of birth: November 29, 1960\n    - Sex: Female\n    - Handedness: Right-handed\n    - Current residence: Rodriguezville\n    - Marital status: In a long-term relationship\n    - Children or dependents: No\n    - Employment status: Not currently employed\n* Medical information:\n    - Allergies: Acetaminophen, latex, pet dander\n    - Current medications: Paxil (20-50 mg per day) taken once daily\n    - Medication adherence: Generally takes Paxil once daily but occasionally misses doses\n* Health history:\n    - Diagnoses: Avoidant personality disorder\n    - Medical events: Hospitalized for severe depressive episode in 2010 at St. Michael's Hospital\n    - Head injuries/concussions: Concussion in 1985, mild head trauma in 1992\n    - Seizure history: Experienced seizures in the past (frequency and timing unclear)\n* Family psychiatric history:\n    - Mother with bipolar disorder\n    - Paternal grandfather with schizophrenia\n    - Maternal aunt with borderline personality disorder\n\nThank you for your time today, Clarisa. Your input has been greatly appreciated.\n\n<STOP>"}
# INTERVIEW HAS ENDED
# SYSTEM:
# Total time taken: 1105.1059379577637
# Final Notes: Here is all the notes taken for this interview. Edit the notes to only include actual notes, not any of the steps that may have been accidentally included. Output the edited notes, thank the patient for their time, then you MUST output '<STOP>'Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
# Head injuries/concussions: Patient experienced a concussion in 1985 and mild head trauma in 1992, both with no reported long-term effects.
# Seizure history: Patient has experienced seizures in the past, which is a sensitive topic for them.
# Seizure information: Patient is unsure of the timing and frequency of their seizures; they find it difficult to discuss due to personal discomfort.
# Family psychiatric history: Mother with bipolar disorder; paternal grandfather with schizophrenia; maternal aunt with borderline personality disorder.
# Sibling information: One sibling, an older brother named Michael, aged 65, living in Toronto, working as an accountant.
# Birthplace: Burtonton, British Columbia, Canada; No known significant birth complications or concerns.
# Early childhood development: Patient is unsure about developmental milestones and reports difficulty with forming friendships.
# Elementary school performance: Average performance with no significant struggles or issues noted; patient mentions earlier developmental difficulties.
# High school experience: Patient did not perform well and had a difficult time, with no clear favorite subject or class.
# Further education: Patient did not pursue any education after high school due to personal challenges.
# Work history: Patient has two previous jobs - 15 years at Bell Canada (1980-1995) and 7 years at the University of British Columbia (2001-2008).
# Relationship history: Married to John Lee (divorced in 1998); in a long-term relationship with Sarah Thompson (2002-2012).
# Hobbies: Reading historical fiction, practicing yoga, and gardening.
# Stress relaxation techniques: Listening to classical music, practicing deep breathing exercises, and taking walks in nature.
# Final thoughts and concerns: Patient appreciates the conversation and feels it has been helpful; no further concerns or topics were mentioned.
# Final thoughts/concerns: Patient expressed appreciation for the conversation and found it helpful for reflection.
#
# Final notes summary:  Here is all the notes taken for this interview. Edit the notes to only include actual notes, not any of the steps that may have been accidentally included. Output the edited notes, thank the patient for their time, then you MUST output '<STOP>'Patient is willing to provide background information but prefers a focused conversation related to their appointment.
# Full name: Clarisa Mora Reig.
# Preferred name: Clarisa
# Date of birth: November 29, 1960.
# Sex: Female
# Handedness: Clarisa is right-handed.
# Current residence: Rodriguezville.
# Marital status: Patient is in a long-term relationship.
# Children or dependents: No.
# Employment status: Clarisa is not currently employed.
# Disability assistance status: Patient does not receive disability assistance.
# Current doctors: Dr. Rachel Kim and Dr. Eric Taylor.
# Current doctors' specialties: Dr. Rachel Kim (general practitioner), Dr. Eric Taylor (psychiatrist).
# Allergies: Patient has allergies to acetaminophen, latex, and pet dander.
# Current medications: Paxil
# Medication details: Paxil, dosage range 20-50mg/day.
# Current medication dosage and frequency: Paxil (20-50 mg per day) taken once daily.
# Medication adherence: Patient generally takes Paxil once daily as part of their routine but admits to occasionally missing doses.
# Health supplements: Patient reports no current use of health supplements.
# Substance use history: Patient acknowledges past substance use, is uncomfortable discussing specifics, and cannot provide current frequency of use.
# Diagnoses: Avoidant personality disorder. Medical events: Hospitalized for severe depressive episode. Family history: Mental health conditions present in the family.
# History of hospitalization: Patient was hospitalized at St. Michael's Hospital in 2010 for a severe depressive episode.
# Treatment plan: Patient started taking Paroxetine (Paxil) during their stay.
# Head injuries/concussions: Patient experienced a concussion in 1985 and mild head trauma in 1992, both with no reported long-term effects.
# Seizure history: Patient has experienced seizures in the past, which is a sensitive topic for them.
# Seizure information: Patient is unsure of the timing and frequency of their seizures; they find it difficult to discuss due to personal discomfort.
# Family psychiatric history: Mother with bipolar disorder; paternal grandfather with schizophrenia; maternal aunt with borderline personality disorder.
# Sibling information: One sibling, an older brother named Michael, aged 65, living in Toronto, working as an accountant.
# Birthplace: Burtonton, British Columbia, Canada; No known significant birth complications or concerns.
# Early childhood development: Patient is unsure about developmental milestones and reports difficulty with forming friendships.
# Elementary school performance: Average performance with no significant struggles or issues noted; patient mentions earlier developmental difficulties.
# High school experience: Patient did not perform well and had a difficult time, with no clear favorite subject or class.
# Further education: Patient did not pursue any education after high school due to personal challenges.
# Work history: Patient has two previous jobs - 15 years at Bell Canada (1980-1995) and 7 years at the University of British Columbia (2001-2008).
# Relationship history: Married to John Lee (divorced in 1998); in a long-term relationship with Sarah Thompson (2002-2012).
# Hobbies: Reading historical fiction, practicing yoga, and gardening.
# Stress relaxation techniques: Listening to classical music, practicing deep breathing exercises, and taking walks in nature.
# Final thoughts and concerns: Patient appreciates the conversation and feels it has been helpful; no further concerns or topics were mentioned.
# Final thoughts/concerns: Patient expressed appreciation for the conversation and found it helpful for reflection.
